# %%
ls

# %% [markdown]
# # HD Training

# %%
#%tb

import importlib
import argparse
from omegaconf import OmegaConf
import os.path as osp
from datasets.inference_dataset import *
from datasets import *
import torch 

args = {'source': 'nuscenes', 'target': 'semantickitti', 'cluster_cfg': './cfg/clust_cfg/cluster_20.yaml', 
        'model_cfg': './cfg/model_cfg/kp_sk_infer.yaml', 'data_cfg_path': './cfg/data_cfg', 'subsample': 1, 
        'save_pred_path': '/root/main/3DLabelProp/results_3DLabelProp', 'train_hd': False, 'test_hd': True, 
        'hd_param': './cfg/hd_param.yaml'}

cfg = OmegaConf.create(args)
cluster_cfg = OmegaConf.load(cfg.cluster_cfg)
model_cfg = OmegaConf.load(cfg.model_cfg)
cfg = OmegaConf.merge(cfg,cluster_cfg,model_cfg)

if __name__ == "__main__":
    #Get info relative to the set
    if cfg.source == "semantickitti":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set = SemanticKITTI(source_data_cfg,'train')
    elif cfg.source == "nuscenes":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set = nuScenes(source_data_cfg,'train')
    else:
        raise  NameError('source dataset not supported')

    if cfg.target == "semantickitti":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set_2 = SemanticKITTI(target_data_cfg,'train')
        target_set = SemanticKITTI(target_data_cfg,'valid')
    elif cfg.target == "nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set_2 = nuScenes(target_data_cfg,'train')
        target_set = nuScenes(target_data_cfg,'valid')
    elif cfg.target == "semanticposs":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semanticposs.yaml"))
        train_set_2 = SemanticPOSS(target_data_cfg,'train')
        target_set = SemanticPOSS(target_data_cfg,'valid')
    elif cfg.target == "semantickitti-nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti-nuscenes.yaml"))
        train_set_2 = SemanticKITTI_Nuscenes(target_data_cfg,'train')
        target_set = SemanticKITTI_Nuscenes(target_data_cfg,'valid')
    elif "pandaset" in cfg.target:
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,cfg.target+".yaml"))
        train_set_2 = Pandaset(target_data_cfg,'train')
        target_set = Pandaset(target_data_cfg,'valid')
    
    else:
        raise  NameError('target dataset not supported')

    #Get info relative to the model
    if cfg.architecture.model == "KPCONV":
        module = importlib.import_module('models.kpconv.kpconv')
        model_information = getattr(module, cfg.architecture.type)()
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        model_information.train_hd = cfg.train_hd
        from models.kpconv_model import SemanticSegmentationModel
        module = importlib.import_module('models.kpconv.architecture')
        model_type = getattr(module, cfg.architecture.type)
        model = SemanticSegmentationModel(model_information,cfg,model_type)
    elif cfg.architecture.model == "SPVCNN":
        module = importlib.import_module('models.spvcnn.spvcnn')
        model_information = getattr(module, cfg.architecture.type)
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        from models.spvcnn_model import SemanticSegmentationSPVCNNModel
        model = SemanticSegmentationSPVCNNModel(model_information,cfg)
    else:
        raise  NameError('model not supported')
        
    # Get HD info
    if cfg.train_hd or cfg.test_hd:
        hd_cfg = OmegaConf.load(cfg.hd_param)
        cfg = OmegaConf.merge(cfg,hd_cfg) 
        from models.HD import OnlineHD
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        #device = torch.device("cpu")
        model_hd = OnlineHD(hd_cfg.n_features, hd_cfg.n_dimensions, hd_cfg.n_classes, epochs = hd_cfg.epochs, device=device)
        
    #print(cfg.hd_block_stop) #The parameters of hd are now part of cfg
    #try:
    #    ius, miu = valid_dataset.compute_results()
    #except:
    
    # Define the path for the "HD" folder
    hd_folder = os.path.join(cfg.save_pred_path, 'HD')
    
    # Define file names for saving the tensors
    weights_path = os.path.join(hd_folder, 'weights.pt')
    encoding_path = os.path.join(hd_folder, 'encoding.pt')

    # Check if the "HD" folder exists
    if not os.path.exists(hd_folder):
        os.makedirs(hd_folder)
        print(f"Folder 'HD' created at {hd_folder}")
    else:
        print(f"Folder 'HD' already exists at {hd_folder}")

    if cfg.train_hd:
        
        output_dataset = InferenceDataset(cfg,train_set,train_set_2,model, model_information, model_hd)
        
        output_dataset.compute_hd_dataset()

        # Save the tensors
        torch.save(model_hd.model.weight, weights_path)
        torch.save(model_hd.encoder.weight, encoding_path)

        print(f"Tensors saved in {hd_folder}")
    
    if cfg.test_hd:
        
        print("CFG: ", cfg.test_hd)
        
        model_hd.model.weight = torch.load(weights_path)
        model_hd.encoder.weight = torch.load(encoding_path)
        
        output_dataset = InferenceDataset(cfg,train_set,target_set,model, model_information, model_hd)
        
        output_dataset.compute_dataset()
        ius, miu = output_dataset.compute_results() # The results are already there?
        print(ius)
        print(miu)
    
    #ius, miu = output_dataset.compute_results() # The results are already there?
    #print(ius)
    #print(miu)
# Out:
# Model ready
# Folder 'HD' already exists at /root/main/3DLabelProp/results_3DLabelProp/HD
# CFG:  True
# Sequence:  ['08']
# Processing dataset semantickitti:   0%|                                                                                       | 0/1 [00:00<?, ?it/s]
# Last:  004070.bin
# Last:  004070
# Sequence: 08, subsample number 1/1:   0%|                                                                                     | 0/5 [00:00<?, ?it/s]
# True
# TrainHD?:  True
# torch.Size([7541])
# X_interme_enc:  torch.Size([7541, 64])
# X_interme_enc:  torch.Size([7541, 128])
# X_interme_enc:  torch.Size([3854, 128])
# X_interme_enc:  torch.Size([3854, 256])
# X_interme_enc:  torch.Size([3854, 256])
# torch.Size([7541, 128])
# torch.Size([128])
# Encoded torch.Size([7541, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7541, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(92153)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([7582])
# X_interme_enc:  torch.Size([7582, 64])
# X_interme_enc:  torch.Size([7582, 128])
# X_interme_enc:  torch.Size([5744, 128])
# X_interme_enc:  torch.Size([5744, 256])
# X_interme_enc:  torch.Size([5744, 256])
# torch.Size([7582, 128])
# torch.Size([128])
# Encoded torch.Size([7582, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7582, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(51816)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([8659])
# X_interme_enc:  torch.Size([8659, 64])
# X_interme_enc:  torch.Size([8659, 128])
# X_interme_enc:  torch.Size([4487, 128])
# X_interme_enc:  torch.Size([4487, 256])
# X_interme_enc:  torch.Size([4487, 256])
# torch.Size([8659, 128])
# torch.Size([128])
# Encoded torch.Size([8659, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8659, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(154245)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([3207])
# X_interme_enc:  torch.Size([3207, 64])
# X_interme_enc:  torch.Size([3207, 128])
# X_interme_enc:  torch.Size([2942, 128])
# X_interme_enc:  torch.Size([2942, 256])
# X_interme_enc:  torch.Size([2942, 256])
# torch.Size([3207, 128])
# torch.Size([128])
# Encoded torch.Size([3207, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([3207, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(35210)
# TrainHD?:  True
# torch.Size([1084])
# X_interme_enc:  torch.Size([1084, 64])
# X_interme_enc:  torch.Size([1084, 128])
# X_interme_enc:  torch.Size([1078, 128])
# X_interme_enc:  torch.Size([1078, 256])
# X_interme_enc:  torch.Size([1078, 256])
# torch.Size([1084, 128])
# torch.Size([128])
# Encoded torch.Size([1084, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1084, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(12885)
# TrainHD?:  True
# torch.Size([7008])
# X_interme_enc:  torch.Size([7008, 64])
# X_interme_enc:  torch.Size([7008, 128])
# X_interme_enc:  torch.Size([5229, 128])
# X_interme_enc:  torch.Size([5229, 256])
# X_interme_enc:  torch.Size([5229, 256])
# torch.Size([7008, 128])
# torch.Size([128])
# Encoded torch.Size([7008, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7008, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(58808)
# TrainHD?:  True
# torch.Size([1228])
# X_interme_enc:  torch.Size([1228, 64])
# X_interme_enc:  torch.Size([1228, 128])
# X_interme_enc:  torch.Size([1210, 128])
# X_interme_enc:  torch.Size([1210, 256])
# X_interme_enc:  torch.Size([1210, 256])
# torch.Size([1228, 128])
# torch.Size([128])
# Encoded torch.Size([1228, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([1228, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(15602)
# TrainHD?:  True
# torch.Size([2682])
# X_interme_enc:  torch.Size([2682, 64])
# X_interme_enc:  torch.Size([2682, 128])
# X_interme_enc:  torch.Size([2505, 128])
# X_interme_enc:  torch.Size([2505, 256])
# X_interme_enc:  torch.Size([2505, 256])
# torch.Size([2682, 128])
# torch.Size([128])
# Encoded torch.Size([2682, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2682, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(19022)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5765])
# X_interme_enc:  torch.Size([5765, 64])
# X_interme_enc:  torch.Size([5765, 128])
# X_interme_enc:  torch.Size([4115, 128])
# X_interme_enc:  torch.Size([4115, 256])
# X_interme_enc:  torch.Size([4115, 256])
# torch.Size([5765, 128])
# torch.Size([128])
# Encoded torch.Size([5765, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5765, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(60214)
# TrainHD?:  True
# torch.Size([1542])
# X_interme_enc:  torch.Size([1542, 64])
# X_interme_enc:  torch.Size([1542, 128])
# X_interme_enc:  torch.Size([1533, 128])
# X_interme_enc:  torch.Size([1533, 256])
# X_interme_enc:  torch.Size([1533, 256])
# torch.Size([1542, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([1542, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1542, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(1086)
# TrainHD?:  True
# torch.Size([9720])
# X_interme_enc:  torch.Size([9720, 64])
# X_interme_enc:  torch.Size([9720, 128])
# X_interme_enc:  torch.Size([4461, 128])
# X_interme_enc:  torch.Size([4461, 256])
# X_interme_enc:  torch.Size([4461, 256])
# torch.Size([9720, 128])
# torch.Size([128])
# Encoded torch.Size([9720, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9720, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(74521)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([6577])
# X_interme_enc:  torch.Size([6577, 64])
# X_interme_enc:  torch.Size([6577, 128])
# X_interme_enc:  torch.Size([3180, 128])
# X_interme_enc:  torch.Size([3180, 256])
# X_interme_enc:  torch.Size([3180, 256])
# torch.Size([6577, 128])
# torch.Size([128])
# Encoded torch.Size([6577, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([6577, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(99620)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([9177])
# X_interme_enc:  torch.Size([9177, 64])
# X_interme_enc:  torch.Size([9177, 128])
# X_interme_enc:  torch.Size([6451, 128])
# X_interme_enc:  torch.Size([6451, 256])
# X_interme_enc:  torch.Size([6451, 256])
# torch.Size([9177, 128])
# torch.Size([128])
# Encoded torch.Size([9177, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9177, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(70037)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([4625])
# X_interme_enc:  torch.Size([4625, 64])
# X_interme_enc:  torch.Size([4625, 128])
# X_interme_enc:  torch.Size([3440, 128])
# X_interme_enc:  torch.Size([3440, 256])
# X_interme_enc:  torch.Size([3440, 256])
# torch.Size([4625, 128])
# torch.Size([128])
# Encoded torch.Size([4625, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([4625, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(58162)
# TrainHD?:  True
# torch.Size([1884])
# X_interme_enc:  torch.Size([1884, 64])
# X_interme_enc:  torch.Size([1884, 128])
# X_interme_enc:  torch.Size([1863, 128])
# X_interme_enc:  torch.Size([1863, 256])
# X_interme_enc:  torch.Size([1863, 256])
# torch.Size([1884, 128])
# torch.Size([128])
# Encoded torch.Size([1884, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([1884, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(15336)
# TrainHD?:  True
# torch.Size([2570])
# X_interme_enc:  torch.Size([2570, 64])
# X_interme_enc:  torch.Size([2570, 128])
# X_interme_enc:  torch.Size([2440, 128])
# X_interme_enc:  torch.Size([2440, 256])
# X_interme_enc:  torch.Size([2440, 256])
# torch.Size([2570, 128])
# torch.Size([128])
# Encoded torch.Size([2570, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2570, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(47104)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5245])
# X_interme_enc:  torch.Size([5245, 64])
# X_interme_enc:  torch.Size([5245, 128])
# X_interme_enc:  torch.Size([3737, 128])
# X_interme_enc:  torch.Size([3737, 256])
# X_interme_enc:  torch.Size([3737, 256])
# torch.Size([5245, 128])
# torch.Size([128])
# Encoded torch.Size([5245, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5245, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(69163)
# TrainHD?:  True
# torch.Size([2339])
# X_interme_enc:  torch.Size([2339, 64])
# X_interme_enc:  torch.Size([2339, 128])
# X_interme_enc:  torch.Size([2165, 128])
# X_interme_enc:  torch.Size([2165, 256])
# X_interme_enc:  torch.Size([2165, 256])
# torch.Size([2339, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([2339, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2339, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(18927)
# TrainHD?:  True
# torch.Size([8932])
# X_interme_enc:  torch.Size([8932, 64])
# X_interme_enc:  torch.Size([8932, 128])
# X_interme_enc:  torch.Size([4132, 128])
# X_interme_enc:  torch.Size([4132, 256])
# X_interme_enc:  torch.Size([4132, 256])
# torch.Size([8932, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([8932, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8932, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(110450)
# TrainHD?:  True
# torch.Size([2867])
# X_interme_enc:  torch.Size([2867, 64])
# X_interme_enc:  torch.Size([2867, 128])
# X_interme_enc:  torch.Size([2597, 128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# X_interme_enc:  torch.Size([2597, 256])
# X_interme_enc:  torch.Size([2597, 256])
# torch.Size([2867, 128])
# torch.Size([128])
# Encoded torch.Size([2867, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2867, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(38972)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
#
# Sequence: 08, subsample number 1/1:  20%|███████████████▍                                                             | 1/5 [00:09<00:39,  9.85s/it]
# True
# TrainHD?:  True
# torch.Size([1859])
# X_interme_enc:  torch.Size([1859, 64])
# X_interme_enc:  torch.Size([1859, 128])
# X_interme_enc:  torch.Size([1836, 128])
# X_interme_enc:  torch.Size([1836, 256])
# X_interme_enc:  torch.Size([1836, 256])
# torch.Size([1859, 128])
# torch.Size([128])
# Encoded torch.Size([1859, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1859, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(2625)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([10712])
# X_interme_enc:  torch.Size([10712, 64])
# X_interme_enc:  torch.Size([10712, 128])
# X_interme_enc:  torch.Size([5520, 128])
# X_interme_enc:  torch.Size([5520, 256])
# X_interme_enc:  torch.Size([5520, 256])
# torch.Size([10712, 128])
# torch.Size([128])
# Encoded torch.Size([10712, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([10712, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(44520)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([9645])
# X_interme_enc:  torch.Size([9645, 64])
# X_interme_enc:  torch.Size([9645, 128])
# X_interme_enc:  torch.Size([6673, 128])
# X_interme_enc:  torch.Size([6673, 256])
# X_interme_enc:  torch.Size([6673, 256])
# torch.Size([9645, 128])
# torch.Size([128])
# Encoded torch.Size([9645, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9645, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(17084)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([9970])
# X_interme_enc:  torch.Size([9970, 64])
# X_interme_enc:  torch.Size([9970, 128])
# X_interme_enc:  torch.Size([4582, 128])
# X_interme_enc:  torch.Size([4582, 256])
# X_interme_enc:  torch.Size([4582, 256])
# torch.Size([9970, 128])
# torch.Size([128])
# Encoded torch.Size([9970, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9970, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(144023)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([1386])
# X_interme_enc:  torch.Size([1386, 64])
# X_interme_enc:  torch.Size([1386, 128])
# X_interme_enc:  torch.Size([1372, 128])
# X_interme_enc:  torch.Size([1372, 256])
# X_interme_enc:  torch.Size([1372, 256])
# torch.Size([1386, 128])
# torch.Size([128])
# Encoded torch.Size([1386, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1386, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(10073)
# TrainHD?:  True
# torch.Size([2126])
# X_interme_enc:  torch.Size([2126, 64])
# X_interme_enc:  torch.Size([2126, 128])
# X_interme_enc:  torch.Size([1952, 128])
# X_interme_enc:  torch.Size([1952, 256])
# X_interme_enc:  torch.Size([1952, 256])
# torch.Size([2126, 128])
# torch.Size([128])
# Encoded torch.Size([2126, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([2126, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(15070)
# TrainHD?:  True
# torch.Size([2644])
# X_interme_enc:  torch.Size([2644, 64])
# X_interme_enc:  torch.Size([2644, 128])
# X_interme_enc:  torch.Size([2502, 128])
# X_interme_enc:  torch.Size([2502, 256])
# X_interme_enc:  torch.Size([2502, 256])
# torch.Size([2644, 128])
# torch.Size([128])
# Encoded torch.Size([2644, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2644, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(42088)
# TrainHD?:  True
# torch.Size([6705])
# X_interme_enc:  torch.Size([6705, 64])
# X_interme_enc:  torch.Size([6705, 128])
# X_interme_enc:  torch.Size([3571, 128])
# X_interme_enc:  torch.Size([3571, 256])
# X_interme_enc:  torch.Size([3571, 256])
# torch.Size([6705, 128])
# torch.Size([128])
# Encoded torch.Size([6705, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([6705, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(32341)
# TrainHD?:  True
# torch.Size([1212])
# X_interme_enc:  torch.Size([1212, 64])
# X_interme_enc:  torch.Size([1212, 128])
# X_interme_enc:  torch.Size([1188, 128])
# X_interme_enc:  torch.Size([1188, 256])
# X_interme_enc:  torch.Size([1188, 256])
# torch.Size([1212, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([1212, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1212, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(19155)
# TrainHD?:  True
# torch.Size([3187])
# X_interme_enc:  torch.Size([3187, 64])
# X_interme_enc:  torch.Size([3187, 128])
# X_interme_enc:  torch.Size([2685, 128])
# X_interme_enc:  torch.Size([2685, 256])
# X_interme_enc:  torch.Size([2685, 256])
# torch.Size([3187, 128])
# torch.Size([128])
# Encoded torch.Size([3187, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([3187, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(48662)
# TrainHD?:  True
# torch.Size([5767])
# X_interme_enc:  torch.Size([5767, 64])
# X_interme_enc:  torch.Size([5767, 128])
# X_interme_enc:  torch.Size([4096, 128])
# X_interme_enc:  torch.Size([4096, 256])
# X_interme_enc:  torch.Size([4096, 256])
# torch.Size([5767, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([5767, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5767, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(25387)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([9064])
# X_interme_enc:  torch.Size([9064, 64])
# X_interme_enc:  torch.Size([9064, 128])
# X_interme_enc:  torch.Size([6456, 128])
# X_interme_enc:  torch.Size([6456, 256])
# X_interme_enc:  torch.Size([6456, 256])
# torch.Size([9064, 128])
# torch.Size([128])
# Encoded torch.Size([9064, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9064, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(129735)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([6600])
# X_interme_enc:  torch.Size([6600, 64])
# X_interme_enc:  torch.Size([6600, 128])
# X_interme_enc:  torch.Size([4720, 128])
# X_interme_enc:  torch.Size([4720, 256])
# X_interme_enc:  torch.Size([4720, 256])
# torch.Size([6600, 128])
# torch.Size([128])
# Encoded torch.Size([6600, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([6600, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(30973)
# TrainHD?:  True
# torch.Size([2574])
# X_interme_enc:  torch.Size([2574, 64])
# X_interme_enc:  torch.Size([2574, 128])
# X_interme_enc:  torch.Size([2449, 128])
# X_interme_enc:  torch.Size([2449, 256])
# X_interme_enc:  torch.Size([2449, 256])
# torch.Size([2574, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([2574, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2574, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(16115)
# TrainHD?:  True
# torch.Size([1075])
# X_interme_enc:  torch.Size([1075, 64])
# X_interme_enc:  torch.Size([1075, 128])
# X_interme_enc:  torch.Size([1069, 128])
# X_interme_enc:  torch.Size([1069, 256])
# X_interme_enc:  torch.Size([1069, 256])
# torch.Size([1075, 128])
# torch.Size([128])
# Encoded torch.Size([1075, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1075, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(15184)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([8538])
# X_interme_enc:  torch.Size([8538, 64])
# X_interme_enc:  torch.Size([8538, 128])
# X_interme_enc:  torch.Size([4032, 128])
# X_interme_enc:  torch.Size([4032, 256])
# X_interme_enc:  torch.Size([4032, 256])
# torch.Size([8538, 128])
# torch.Size([128])
# Encoded torch.Size([8538, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8538, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(25634)
# TrainHD?:  True
# torch.Size([1201])
# X_interme_enc:  torch.Size([1201, 64])
# X_interme_enc:  torch.Size([1201, 128])
# X_interme_enc:  torch.Size([1193, 128])
# X_interme_enc:  torch.Size([1193, 256])
# X_interme_enc:  torch.Size([1193, 256])
# torch.Size([1201, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([1201, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([1201, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(744)
# TrainHD?:  True
# torch.Size([3066])
# X_interme_enc:  torch.Size([3066, 64])
# X_interme_enc:  torch.Size([3066, 128])
# X_interme_enc:  torch.Size([2828, 128])
# X_interme_enc:  torch.Size([2828, 256])
# X_interme_enc:  torch.Size([2828, 256])
# torch.Size([3066, 128])
# torch.Size([128])
# Encoded torch.Size([3066, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([3066, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(34944)
# TrainHD?:  True
# torch.Size([8037])
# X_interme_enc:  torch.Size([8037, 64])
# X_interme_enc:  torch.Size([8037, 128])
# X_interme_enc:  torch.Size([5850, 128])
# X_interme_enc:  torch.Size([5850, 256])
# X_interme_enc:  torch.Size([5850, 256])
# torch.Size([8037, 128])
# torch.Size([128])
# Encoded torch.Size([8037, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8037, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(4183)
# TrainHD?:  True
# torch.Size([4324])
# X_interme_enc:  torch.Size([4324, 64])
# X_interme_enc:  torch.Size([4324, 128])
# X_interme_enc:  torch.Size([2952, 128])
# X_interme_enc:  torch.Size([2952, 256])
# X_interme_enc:  torch.Size([2952, 256])
# torch.Size([4324, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([4324, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([4324, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(75224)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
#
# Sequence: 08, subsample number 1/1:  40%|██████████████████████████████▊                                              | 2/5 [00:19<00:29,  9.92s/it]
# True
# TrainHD?:  True
# torch.Size([15491])
# X_interme_enc:  torch.Size([15491, 64])
# X_interme_enc:  torch.Size([15491, 128])
# X_interme_enc:  torch.Size([9856, 128])
# X_interme_enc:  torch.Size([9856, 256])
# X_interme_enc:  torch.Size([9856, 256])
# torch.Size([15491, 128])
# torch.Size([128])
# Encoded torch.Size([15491, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([15491, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(150939)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([4508])
# X_interme_enc:  torch.Size([4508, 64])
# X_interme_enc:  torch.Size([4508, 128])
# X_interme_enc:  torch.Size([3637, 128])
# X_interme_enc:  torch.Size([3637, 256])
# X_interme_enc:  torch.Size([3637, 256])
# torch.Size([4508, 128])
# torch.Size([128])
# Encoded torch.Size([4508, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([4508, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(77447)
# TrainHD?:  True
# torch.Size([2529])
# X_interme_enc:  torch.Size([2529, 64])
# X_interme_enc:  torch.Size([2529, 128])
# X_interme_enc:  torch.Size([2487, 128])
# X_interme_enc:  torch.Size([2487, 256])
# X_interme_enc:  torch.Size([2487, 256])
# torch.Size([2529, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([2529, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2529, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(22290)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([15662])
# X_interme_enc:  torch.Size([15662, 64])
# X_interme_enc:  torch.Size([15662, 128])
# X_interme_enc:  torch.Size([9777, 128])
# X_interme_enc:  torch.Size([9777, 256])
# X_interme_enc:  torch.Size([9777, 256])
# torch.Size([15662, 128])
# torch.Size([128])
# Encoded torch.Size([15662, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([15662, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(180845)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([2087])
# X_interme_enc:  torch.Size([2087, 64])
# X_interme_enc:  torch.Size([2087, 128])
# X_interme_enc:  torch.Size([1950, 128])
# X_interme_enc:  torch.Size([1950, 256])
# X_interme_enc:  torch.Size([1950, 256])
# torch.Size([2087, 128])
# torch.Size([128])
# Encoded torch.Size([2087, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2087, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(16970)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([10321])
# X_interme_enc:  torch.Size([10321, 64])
# X_interme_enc:  torch.Size([10321, 128])
# X_interme_enc:  torch.Size([5940, 128])
# X_interme_enc:  torch.Size([5940, 256])
# X_interme_enc:  torch.Size([5940, 256])
# torch.Size([10321, 128])
# torch.Size([128])
# Encoded torch.Size([10321, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([10321, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(54191)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([2519])
# X_interme_enc:  torch.Size([2519, 64])
# X_interme_enc:  torch.Size([2519, 128])
# X_interme_enc:  torch.Size([2469, 128])
# X_interme_enc:  torch.Size([2469, 256])
# X_interme_enc:  torch.Size([2469, 256])
# torch.Size([2519, 128])
# torch.Size([128])
# Encoded torch.Size([2519, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2519, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(35229)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([6054])
# X_interme_enc:  torch.Size([6054, 64])
# X_interme_enc:  torch.Size([6054, 128])
# X_interme_enc:  torch.Size([5127, 128])
# X_interme_enc:  torch.Size([5127, 256])
# X_interme_enc:  torch.Size([5127, 256])
# torch.Size([6054, 128])
# torch.Size([128])
# Encoded torch.Size([6054, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([6054, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(35666)
# TrainHD?:  True
# torch.Size([3468])
# X_interme_enc:  torch.Size([3468, 64])
# X_interme_enc:  torch.Size([3468, 128])
# X_interme_enc:  torch.Size([3386, 128])
# X_interme_enc:  torch.Size([3386, 256])
# X_interme_enc:  torch.Size([3386, 256])
# torch.Size([3468, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([3468, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([3468, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(56528)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([14800])
# X_interme_enc:  torch.Size([14800, 64])
# X_interme_enc:  torch.Size([14800, 128])
# X_interme_enc:  torch.Size([6149, 128])
# X_interme_enc:  torch.Size([6149, 256])
# X_interme_enc:  torch.Size([6149, 256])
# torch.Size([14800, 128])
# torch.Size([128])
# Encoded torch.Size([14800, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([14800, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(244647)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([17672])
# X_interme_enc:  torch.Size([17672, 64])
# X_interme_enc:  torch.Size([17672, 128])
# X_interme_enc:  torch.Size([7701, 128])
# X_interme_enc:  torch.Size([7701, 256])
# X_interme_enc:  torch.Size([7701, 256])
# torch.Size([17672, 128])
# torch.Size([128])
# Encoded torch.Size([17672, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([17672, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(241113)
# TrainHD?:  True
# torch.Size([12436])
# X_interme_enc:  torch.Size([12436, 64])
# X_interme_enc:  torch.Size([12436, 128])
# X_interme_enc:  torch.Size([7345, 128])
# X_interme_enc:  torch.Size([7345, 256])
# X_interme_enc:  torch.Size([7345, 256])
# torch.Size([12436, 128])
# torch.Size([128])
# Encoded torch.Size([12436, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([12436, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(200814)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5035])
# X_interme_enc:  torch.Size([5035, 64])
# X_interme_enc:  torch.Size([5035, 128])
# X_interme_enc:  torch.Size([4515, 128])
# X_interme_enc:  torch.Size([4515, 256])
# X_interme_enc:  torch.Size([4515, 256])
# torch.Size([5035, 128])
# torch.Size([128])
# Encoded torch.Size([5035, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5035, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(11897)
# TrainHD?:  True
# torch.Size([2539])
# X_interme_enc:  torch.Size([2539, 64])
# X_interme_enc:  torch.Size([2539, 128])
# X_interme_enc:  torch.Size([2360, 128])
# X_interme_enc:  torch.Size([2360, 256])
# X_interme_enc:  torch.Size([2360, 256])
# torch.Size([2539, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([2539, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2539, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(744)
# TrainHD?:  True
# torch.Size([5351])
# X_interme_enc:  torch.Size([5351, 64])
# X_interme_enc:  torch.Size([5351, 128])
# X_interme_enc:  torch.Size([4110, 128])
# X_interme_enc:  torch.Size([4110, 256])
# X_interme_enc:  torch.Size([4110, 256])
# torch.Size([5351, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([5351, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5351, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(76858)
# TrainHD?:  True
# torch.Size([6470])
# X_interme_enc:  torch.Size([6470, 64])
# X_interme_enc:  torch.Size([6470, 128])
# X_interme_enc:  torch.Size([5101, 128])
# X_interme_enc:  torch.Size([5101, 256])
# X_interme_enc:  torch.Size([5101, 256])
# torch.Size([6470, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([6470, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([6470, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(38801)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([17728])
# X_interme_enc:  torch.Size([17728, 64])
# X_interme_enc:  torch.Size([17728, 128])
# X_interme_enc:  torch.Size([7190, 128])
# X_interme_enc:  torch.Size([7190, 256])
# X_interme_enc:  torch.Size([7190, 256])
# torch.Size([17728, 128])
# torch.Size([128])
# Encoded torch.Size([17728, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([17728, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(141344)
# TrainHD?:  True
# torch.Size([14646])
# X_interme_enc:  torch.Size([14646, 64])
# X_interme_enc:  torch.Size([14646, 128])
# X_interme_enc:  torch.Size([9309, 128])
# X_interme_enc:  torch.Size([9309, 256])
# X_interme_enc:  torch.Size([9309, 256])
# torch.Size([14646, 128])
# torch.Size([128])
# Encoded torch.Size([14646, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([14646, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(79803)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([17642])
# X_interme_enc:  torch.Size([17642, 64])
# X_interme_enc:  torch.Size([17642, 128])
# X_interme_enc:  torch.Size([10583, 128])
# X_interme_enc:  torch.Size([10583, 256])
# X_interme_enc:  torch.Size([10583, 256])
# torch.Size([17642, 128])
# torch.Size([128])
# Encoded torch.Size([17642, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([17642, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(286846)
# TrainHD?:  True
# torch.Size([2054])
# X_interme_enc:  torch.Size([2054, 64])
# X_interme_enc:  torch.Size([2054, 128])
# X_interme_enc:  torch.Size([1924, 128])
# X_interme_enc:  torch.Size([1924, 256])
# X_interme_enc:  torch.Size([1924, 256])
# torch.Size([2054, 128])
# torch.Size([128])
# Encoded torch.Size([2054, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2054, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(25995)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
#
# Sequence: 08, subsample number 1/1:  60%|██████████████████████████████████████████████▏                              | 3/5 [00:38<00:27, 13.80s/it]
# True
# TrainHD?:  True
# torch.Size([14187])
# X_interme_enc:  torch.Size([14187, 64])
# X_interme_enc:  torch.Size([14187, 128])
# X_interme_enc:  torch.Size([6818, 128])
# X_interme_enc:  torch.Size([6818, 256])
# X_interme_enc:  torch.Size([6818, 256])
# torch.Size([14187, 128])
# torch.Size([128])
# Encoded torch.Size([14187, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([14187, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(227946)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5030])
# X_interme_enc:  torch.Size([5030, 64])
# X_interme_enc:  torch.Size([5030, 128])
# X_interme_enc:  torch.Size([4560, 128])
# X_interme_enc:  torch.Size([4560, 256])
# X_interme_enc:  torch.Size([4560, 256])
# torch.Size([5030, 128])
# torch.Size([128])
# Encoded torch.Size([5030, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5030, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(44558)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([18414])
# X_interme_enc:  torch.Size([18414, 64])
# X_interme_enc:  torch.Size([18414, 128])
# X_interme_enc:  torch.Size([11863, 128])
# X_interme_enc:  torch.Size([11863, 256])
# X_interme_enc:  torch.Size([11863, 256])
# torch.Size([18414, 128])
# torch.Size([128])
# Encoded torch.Size([18414, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([18414, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(277878)
# TrainHD?:  True
# torch.Size([5278])
# X_interme_enc:  torch.Size([5278, 64])
# X_interme_enc:  torch.Size([5278, 128])
# X_interme_enc:  torch.Size([4608, 128])
# X_interme_enc:  torch.Size([4608, 256])
# X_interme_enc:  torch.Size([4608, 256])
# torch.Size([5278, 128])
# torch.Size([128])
# Encoded torch.Size([5278, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5278, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(78378)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([14880])
# X_interme_enc:  torch.Size([14880, 64])
# X_interme_enc:  torch.Size([14880, 128])
# X_interme_enc:  torch.Size([9977, 128])
# X_interme_enc:  torch.Size([9977, 256])
# X_interme_enc:  torch.Size([9977, 256])
# torch.Size([14880, 128])
# torch.Size([128])
# Encoded torch.Size([14880, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([14880, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(45641)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([8793])
# X_interme_enc:  torch.Size([8793, 64])
# X_interme_enc:  torch.Size([8793, 128])
# X_interme_enc:  torch.Size([6021, 128])
# X_interme_enc:  torch.Size([6021, 256])
# X_interme_enc:  torch.Size([6021, 256])
# torch.Size([8793, 128])
# torch.Size([128])
# Encoded torch.Size([8793, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8793, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(21416)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([9988])
# X_interme_enc:  torch.Size([9988, 64])
# X_interme_enc:  torch.Size([9988, 128])
# X_interme_enc:  torch.Size([3935, 128])
# X_interme_enc:  torch.Size([3935, 256])
# X_interme_enc:  torch.Size([3935, 256])
# torch.Size([9988, 128])
# torch.Size([128])
# Encoded torch.Size([9988, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([9988, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(136195)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([10366])
# X_interme_enc:  torch.Size([10366, 64])
# X_interme_enc:  torch.Size([10366, 128])
# X_interme_enc:  torch.Size([7776, 128])
# X_interme_enc:  torch.Size([7776, 256])
# X_interme_enc:  torch.Size([7776, 256])
# torch.Size([10366, 128])
# torch.Size([128])
# Encoded torch.Size([10366, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([10366, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(179572)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([14333])
# X_interme_enc:  torch.Size([14333, 64])
# X_interme_enc:  torch.Size([14333, 128])
# X_interme_enc:  torch.Size([6216, 128])
# X_interme_enc:  torch.Size([6216, 256])
# X_interme_enc:  torch.Size([6216, 256])
# torch.Size([14333, 128])
# torch.Size([128])
# Encoded torch.Size([14333, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([14333, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(991)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([2551])
# X_interme_enc:  torch.Size([2551, 64])
# X_interme_enc:  torch.Size([2551, 128])
# X_interme_enc:  torch.Size([2452, 128])
# X_interme_enc:  torch.Size([2452, 256])
# X_interme_enc:  torch.Size([2452, 256])
# torch.Size([2551, 128])
# torch.Size([128])
# Encoded torch.Size([2551, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2551, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(23772)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5629])
# X_interme_enc:  torch.Size([5629, 64])
# X_interme_enc:  torch.Size([5629, 128])
# X_interme_enc:  torch.Size([4929, 128])
# X_interme_enc:  torch.Size([4929, 256])
# X_interme_enc:  torch.Size([4929, 256])
# torch.Size([5629, 128])
# torch.Size([128])
# Encoded torch.Size([5629, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5629, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(45337)
# TrainHD?:  True
# torch.Size([2458])
# X_interme_enc:  torch.Size([2458, 64])
# X_interme_enc:  torch.Size([2458, 128])
# X_interme_enc:  torch.Size([2292, 128])
# X_interme_enc:  torch.Size([2292, 256])
# X_interme_enc:  torch.Size([2292, 256])
# torch.Size([2458, 128])
# torch.Size([128])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# Encoded torch.Size([2458, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([2458, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(12581)
# TrainHD?:  True
# torch.Size([4609])
# X_interme_enc:  torch.Size([4609, 64])
# X_interme_enc:  torch.Size([4609, 128])
# X_interme_enc:  torch.Size([4266, 128])
# X_interme_enc:  torch.Size([4266, 256])
# X_interme_enc:  torch.Size([4266, 256])
# torch.Size([4609, 128])
# ...
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([13126])
# X_interme_enc:  torch.Size([13126, 64])
# X_interme_enc:  torch.Size([13126, 128])
# X_interme_enc:  torch.Size([6387, 128])
# X_interme_enc:  torch.Size([6387, 256])
# X_interme_enc:  torch.Size([6387, 256])
# torch.Size([13126, 128])
# torch.Size([128])
# Encoded torch.Size([13126, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([13126, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(230226)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([8871])
# X_interme_enc:  torch.Size([8871, 64])
# X_interme_enc:  torch.Size([8871, 128])
# X_interme_enc:  torch.Size([5619, 128])
# X_interme_enc:  torch.Size([5619, 256])
# X_interme_enc:  torch.Size([5619, 256])
# torch.Size([8871, 128])
# torch.Size([128])
# Encoded torch.Size([8871, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8871, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(152345)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([7219])
# X_interme_enc:  torch.Size([7219, 64])
# X_interme_enc:  torch.Size([7219, 128])
# X_interme_enc:  torch.Size([5666, 128])
# X_interme_enc:  torch.Size([5666, 256])
# X_interme_enc:  torch.Size([5666, 256])
# torch.Size([7219, 128])
# torch.Size([128])
# Encoded torch.Size([7219, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7219, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(48852)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
#
# Sequence: 08, subsample number 1/1:  80%|█████████████████████████████████████████████████████████████▌               | 4/5 [00:55<00:15, 15.35s/it]
# True
# TrainHD?:  True
# torch.Size([8052])
# X_interme_enc:  torch.Size([8052, 64])
# X_interme_enc:  torch.Size([8052, 128])
# X_interme_enc:  torch.Size([5673, 128])
# X_interme_enc:  torch.Size([5673, 256])
# X_interme_enc:  torch.Size([5673, 256])
# torch.Size([8052, 128])
# torch.Size([128])
# Encoded torch.Size([8052, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8052, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(23392)
# TrainHD?:  True
# torch.Size([3346])
# X_interme_enc:  torch.Size([3346, 64])
# X_interme_enc:  torch.Size([3346, 128])
# X_interme_enc:  torch.Size([2912, 128])
# X_interme_enc:  torch.Size([2912, 256])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# X_interme_enc:  torch.Size([2912, 256])
# torch.Size([3346, 128])
# torch.Size([128])
# Encoded torch.Size([3346, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([3346, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(18832)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([7474])
# X_interme_enc:  torch.Size([7474, 64])
# X_interme_enc:  torch.Size([7474, 128])
# X_interme_enc:  torch.Size([5799, 128])
# X_interme_enc:  torch.Size([5799, 256])
# X_interme_enc:  torch.Size([5799, 256])
# torch.Size([7474, 128])
# torch.Size([128])
# Encoded torch.Size([7474, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7474, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(15640)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([15262])
# X_interme_enc:  torch.Size([15262, 64])
# X_interme_enc:  torch.Size([15262, 128])
# X_interme_enc:  torch.Size([8509, 128])
# X_interme_enc:  torch.Size([8509, 256])
# X_interme_enc:  torch.Size([8509, 256])
# torch.Size([15262, 128])
# torch.Size([128])
# Encoded torch.Size([15262, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([15262, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(261880)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([18565])
# X_interme_enc:  torch.Size([18565, 64])
# X_interme_enc:  torch.Size([18565, 128])
# X_interme_enc:  torch.Size([11604, 128])
# X_interme_enc:  torch.Size([11604, 256])
# X_interme_enc:  torch.Size([11604, 256])
# torch.Size([18565, 128])
# torch.Size([128])
# Encoded torch.Size([18565, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([18565, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(310596)
# TrainHD?:  True
# torch.Size([28348])
# X_interme_enc:  torch.Size([28348, 64])
# X_interme_enc:  torch.Size([28348, 128])
# X_interme_enc:  torch.Size([17285, 128])
# X_interme_enc:  torch.Size([17285, 256])
# X_interme_enc:  torch.Size([17285, 256])
# torch.Size([28348, 128])
# torch.Size([128])
# Encoded torch.Size([28348, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([28348, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(493889)
# TrainHD?:  True
# torch.Size([7016])
# X_interme_enc:  torch.Size([7016, 64])
# X_interme_enc:  torch.Size([7016, 128])
# X_interme_enc:  torch.Size([6042, 128])
# X_interme_enc:  torch.Size([6042, 256])
# X_interme_enc:  torch.Size([6042, 256])
# torch.Size([7016, 128])
# torch.Size([128])
# Encoded torch.Size([7016, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([7016, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(90804)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([16304])
# X_interme_enc:  torch.Size([16304, 64])
# X_interme_enc:  torch.Size([16304, 128])
# X_interme_enc:  torch.Size([6564, 128])
# X_interme_enc:  torch.Size([6564, 256])
# X_interme_enc:  torch.Size([6564, 256])
# torch.Size([16304, 128])
# torch.Size([128])
# Encoded torch.Size([16304, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([16304, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(253881)
# TrainHD?:  True
# torch.Size([15437])
# X_interme_enc:  torch.Size([15437, 64])
# X_interme_enc:  torch.Size([15437, 128])
# X_interme_enc:  torch.Size([9394, 128])
# X_interme_enc:  torch.Size([9394, 256])
# X_interme_enc:  torch.Size([9394, 256])
# torch.Size([15437, 128])
# torch.Size([128])
# Encoded torch.Size([15437, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([15437, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(274648)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([3937])
# X_interme_enc:  torch.Size([3937, 64])
# X_interme_enc:  torch.Size([3937, 128])
# X_interme_enc:  torch.Size([3695, 128])
# X_interme_enc:  torch.Size([3695, 256])
# X_interme_enc:  torch.Size([3695, 256])
# torch.Size([3937, 128])
# torch.Size([128])
# Encoded torch.Size([3937, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([3937, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(61335)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([18417])
# X_interme_enc:  torch.Size([18417, 64])
# X_interme_enc:  torch.Size([18417, 128])
# X_interme_enc:  torch.Size([11628, 128])
# X_interme_enc:  torch.Size([11628, 256])
# X_interme_enc:  torch.Size([11628, 256])
# torch.Size([18417, 128])
# torch.Size([128])
# Encoded torch.Size([18417, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([18417, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(324979)
# TrainHD?:  True
# torch.Size([3440])
# X_interme_enc:  torch.Size([3440, 64])
# X_interme_enc:  torch.Size([3440, 128])
# X_interme_enc:  torch.Size([3152, 128])
# X_interme_enc:  torch.Size([3152, 256])
# X_interme_enc:  torch.Size([3152, 256])
# torch.Size([3440, 128])
# torch.Size([128])
# Encoded torch.Size([3440, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([3440, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(16514)
# TrainHD?:  True
# torch.Size([16865])
# X_interme_enc:  torch.Size([16865, 64])
# X_interme_enc:  torch.Size([16865, 128])
# X_interme_enc:  torch.Size([6626, 128])
# X_interme_enc:  torch.Size([6626, 256])
# X_interme_enc:  torch.Size([6626, 256])
# torch.Size([16865, 128])
# torch.Size([128])
# Encoded torch.Size([16865, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([16865, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(86472)
# TrainHD?:  True
# torch.Size([8301])
# X_interme_enc:  torch.Size([8301, 64])
# X_interme_enc:  torch.Size([8301, 128])
# X_interme_enc:  torch.Size([6074, 128])
# X_interme_enc:  torch.Size([6074, 256])
# X_interme_enc:  torch.Size([6074, 256])
# torch.Size([8301, 128])
# torch.Size([128])
# Encoded torch.Size([8301, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8301, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(41727)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([19965])
# X_interme_enc:  torch.Size([19965, 64])
# X_interme_enc:  torch.Size([19965, 128])
# X_interme_enc:  torch.Size([7831, 128])
# X_interme_enc:  torch.Size([7831, 256])
# X_interme_enc:  torch.Size([7831, 256])
# torch.Size([19965, 128])
# torch.Size([128])
# Encoded torch.Size([19965, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([19965, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(211758)
# TrainHD?:  True
# torch.Size([8941])
# X_interme_enc:  torch.Size([8941, 64])
# X_interme_enc:  torch.Size([8941, 128])
# X_interme_enc:  torch.Size([7630, 128])
# X_interme_enc:  torch.Size([7630, 256])
# X_interme_enc:  torch.Size([7630, 256])
# torch.Size([8941, 128])
# torch.Size([128])
# Encoded torch.Size([8941, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([8941, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(124529)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([3779])
# X_interme_enc:  torch.Size([3779, 64])
# X_interme_enc:  torch.Size([3779, 128])
# X_interme_enc:  torch.Size([3504, 128])
# X_interme_enc:  torch.Size([3504, 256])
# X_interme_enc:  torch.Size([3504, 256])
# torch.Size([3779, 128])
# torch.Size([128])
# Encoded torch.Size([3779, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([3779, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(27876)
# TrainHD?:  True
# torch.Size([13781])
# X_interme_enc:  torch.Size([13781, 64])
# X_interme_enc:  torch.Size([13781, 128])
# X_interme_enc:  torch.Size([5528, 128])
# X_interme_enc:  torch.Size([5528, 256])
# X_interme_enc:  torch.Size([5528, 256])
# torch.Size([13781, 128])
# torch.Size([128])
# Encoded torch.Size([13781, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([13781, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(85522)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([5006])
# X_interme_enc:  torch.Size([5006, 64])
# X_interme_enc:  torch.Size([5006, 128])
# X_interme_enc:  torch.Size([4703, 128])
# X_interme_enc:  torch.Size([4703, 256])
# X_interme_enc:  torch.Size([4703, 256])
# torch.Size([5006, 128])
# torch.Size([128])
# Encoded torch.Size([5006, 2000])
# Weights torch.Size([19, 2000])
# y torch.Size([5006, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(33633)
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# TrainHD?:  True
# torch.Size([16701])
# X_interme_enc:  torch.Size([16701, 64])
# X_interme_enc:  torch.Size([16701, 128])
# X_interme_enc:  torch.Size([7088, 128])
# X_interme_enc:  torch.Size([7088, 256])
# X_interme_enc:  torch.Size([7088, 256])
# torch.Size([16701, 128])
# torch.Size([128])
# Encoded torch.Size([16701, 2000])
# Weights torch.Size([19, 2000])
# /root/anaconda3/envs/3DLabelProp/lib/python3.7/site-packages/torchhd/tensors/map.py:375: UserWarning: The norm of a vector is nearly zero, this could indicate a bug.
#   "The norm of a vector is nearly zero, this could indicate a bug."
# y torch.Size([16701, 19])
# All equal? MAPTensor(True)
# Infered: MAPTensor(10852)
# Sequence: 08, subsample number 1/1: 100%|█████████████████████████████████████████████████████████████████████████████| 5/5 [01:20<00:00, 18.58s/it]
# Processing dataset semantickitti: 100%|███████████████████████████████████████████████████████████████████████████████| 1/1 [01:22<00:00, 82.97s/it]
# The length of frame list is:  5
# [0.         0.00066957 0.                nan 0.                nan
#  0.00187091 0.                nan 0.00145792 0.         0.00054602
#  0.         0.         0.         0.         0.         0.00807603
#  0.        ]
# 0.0007887782391443061

# %% [markdown]
# # HD Forward

# %%
#%tb

import importlib
import argparse
from omegaconf import OmegaConf
import os.path as osp
from datasets.inference_dataset import *
from datasets import *
import torch 

args = {'source': 'nuscenes', 'target': 'semantickitti', 'cluster_cfg': './cfg/clust_cfg/cluster_20.yaml', 
        'model_cfg': './cfg/model_cfg/kp_sk_infer.yaml', 'data_cfg_path': './cfg/data_cfg', 'subsample': 1, 
        'save_pred_path': '/root/main/3DLabelProp/results_3DLabelProp', 'train_hd': True, 'test_hd': False, 
        'hd_param': './cfg/hd_param.yaml'}

cfg = OmegaConf.create(args)
cluster_cfg = OmegaConf.load(cfg.cluster_cfg)
model_cfg = OmegaConf.load(cfg.model_cfg)
cfg = OmegaConf.merge(cfg,cluster_cfg,model_cfg)

if __name__ == "__main__":
    #Get info relative to the set
    if cfg.source == "semantickitti":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set = SemanticKITTI(source_data_cfg,'train')
    elif cfg.source == "nuscenes":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set = nuScenes(source_data_cfg,'train')
    else:
        raise  NameError('source dataset not supported')

    if cfg.target == "semantickitti":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set_2 = SemanticKITTI(target_data_cfg,'train')
    elif cfg.target == "nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set_2 = nuScenes(target_data_cfg,'train')
    elif cfg.target == "semanticposs":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semanticposs.yaml"))
        train_set_2 = SemanticPOSS(target_data_cfg,'train')
    elif cfg.target == "semantickitti-nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti-nuscenes.yaml"))
        train_set_2 = SemanticKITTI_Nuscenes(target_data_cfg,'train')
    elif "pandaset" in cfg.target:
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,cfg.target+".yaml"))
        train_set_2 = Pandaset(target_data_cfg,'train')
    
    else:
        raise  NameError('target dataset not supported')

    #Get info relative to the model
    if cfg.architecture.model == "KPCONV":
        module = importlib.import_module('models.kpconv.kpconv')
        model_information = getattr(module, cfg.architecture.type)()
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        model_information.train_hd = cfg.train_hd
        from models.kpconv_model import SemanticSegmentationModel
        module = importlib.import_module('models.kpconv.architecture')
        model_type = getattr(module, cfg.architecture.type)
        model = SemanticSegmentationModel(model_information,cfg,model_type)
    elif cfg.architecture.model == "SPVCNN":
        module = importlib.import_module('models.spvcnn.spvcnn')
        model_information = getattr(module, cfg.architecture.type)
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        from models.spvcnn_model import SemanticSegmentationSPVCNNModel
        model = SemanticSegmentationSPVCNNModel(model_information,cfg)
    else:
        raise  NameError('model not supported')
        
    # Get HD info
    if cfg.train_hd:
        hd_cfg = OmegaConf.load(cfg.hd_param)
        cfg = OmegaConf.merge(cfg,hd_cfg) 
        from models.HD import OnlineHD
        #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        device = torch.device("cpu")
        model_hd = OnlineHD(hd_cfg.n_features, hd_cfg.n_dimensions, hd_cfg.n_classes, epochs = hd_cfg.epochs, device=device)
        
    #print(cfg.hd_block_stop) #The parameters of hd are now part of cfg

    output_dataset = InferenceDataset(cfg,train_set,train_set_2,model, model_information, model_hd)
    #try:
    #    ius, miu = valid_dataset.compute_results()
    #except:
    output_dataset.compute_dataset()
    ius, miu = output_dataset.compute_results() # The results are already there?
    print(ius)
    print(miu)
