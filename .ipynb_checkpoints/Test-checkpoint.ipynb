# %%
ls
# Out:
# README.md   cpp_wrappers/  images/   mapping/   requirements.txt   trainer/
# Test.ipynb  datasets/      infer.py  models/    semantickitti.zip  utils/
# cfg/        debug.py       kernels/  nautilus/  train.py

# %% [markdown]
# # Test for HD Training

# %%
#%tb

import importlib
import argparse
from omegaconf import OmegaConf
import os.path as osp
from datasets.inference_dataset import *
from datasets import *
import torch 

args = {'source': 'nuscenes', 'target': 'semantickitti', 'cluster_cfg': './cfg/clust_cfg/cluster_20.yaml', 'model_cfg': './cfg/model_cfg/kp_sk_infer.yaml', 'data_cfg_path': './cfg/data_cfg', 'subsample': 1, 'save_pred_path': '/root/main/3DLabelProp/results_3DLabelProp'}

cfg = OmegaConf.create(args)
cluster_cfg = OmegaConf.load(cfg.cluster_cfg)
model_cfg = OmegaConf.load(cfg.model_cfg)
cfg = OmegaConf.merge(cfg,cluster_cfg,model_cfg)
if __name__ == "__main__":
    #Get info relative to the set
    if cfg.source == "semantickitti":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set = SemanticKITTI(source_data_cfg,'train')
    elif cfg.source == "nuscenes":
        source_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set = nuScenes(source_data_cfg,'train')
    else:
        raise  NameError('source dataset not supported')

    if cfg.target == "semantickitti":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti.yaml"))
        train_set_2 = SemanticKITTI(target_data_cfg,'train')
    elif cfg.target == "nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"nuscenes.yaml"))
        train_set_2 = nuScenes(target_data_cfg,'train')
    elif cfg.target == "semanticposs":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semanticposs.yaml"))
        train_set_2 = SemanticPOSS(target_data_cfg,'train')
    elif cfg.target == "semantickitti-nuscenes":
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,"semantic-kitti-nuscenes.yaml"))
        train_set_2 = SemanticKITTI_Nuscenes(target_data_cfg,'train')
    elif "pandaset" in cfg.target:
        target_data_cfg = OmegaConf.load(osp.join(cfg.data_cfg_path,cfg.target+".yaml"))
        train_set_2 = Pandaset(target_data_cfg,'train')
    
    else:
        raise  NameError('target dataset not supported')

    #Get info relative to the model
    if cfg.architecture.model == "KPCONV":
        module = importlib.import_module('models.kpconv.kpconv')
        model_information = getattr(module, cfg.architecture.type)()
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        from models.kpconv_model import SemanticSegmentationModel
        module = importlib.import_module('models.kpconv.architecture')
        model_type = getattr(module, cfg.architecture.type)
        model = SemanticSegmentationModel(model_information,cfg,model_type)
    elif cfg.architecture.model == "SPVCNN":
        module = importlib.import_module('models.spvcnn.spvcnn')
        model_information = getattr(module, cfg.architecture.type)
        model_information.num_classes = train_set.get_n_label()
        model_information.ignore_label = -1
        model_information.in_features_dim = model_cfg.architecture.n_features
        from models.spvcnn_model import SemanticSegmentationSPVCNNModel
        model = SemanticSegmentationSPVCNNModel(model_information,cfg)
    else:
        raise  NameError('model not supported')

    output_dataset = InferenceDataset(cfg,train_set,train_set_2,model,model_information)
    #try:
    #    ius, miu = valid_dataset.compute_results()
    #except:
    output_dataset.compute_dataset()
    ius, miu = output_dataset.compute_results() # The results are already there?
    print(ius)
    print(miu)
# Out:
# Model ready
# Sequence:  ['08']
# Processing dataset semantickitti:   0%|                                                           | 0/1 [00:00<?, ?it/s]
# Sequence: 08, subsample number 1/1:   0%|                                                      | 0/4071 [00:00<?, ?it/s]
# X_init:  5
# torch.Size([966, 3])
# X_interme_enc:  torch.Size([966, 64])
# X_interme_enc:  torch.Size([966, 128])
# X_interme_enc:  torch.Size([960, 128])
# X_interme_enc:  torch.Size([960, 256])
# X_interme_enc:  torch.Size([960, 256])
# X_interme_enc:  torch.Size([912, 256])
# X_interme_enc:  torch.Size([912, 512])
# X_interme_enc:  torch.Size([912, 512])
# X_interme_enc:  torch.Size([729, 512])
# X_interme_enc:  torch.Size([729, 1024])
# X_interme_enc:  torch.Size([729, 1024])
# X_interme_enc:  torch.Size([466, 1024])
# X_interme_enc:  torch.Size([466, 2048])
# X_interme_dec:  torch.Size([729, 2048])
# X_interme_dec:  torch.Size([729, 1024])
# X_interme_dec:  torch.Size([912, 1024])
# X_interme_dec:  torch.Size([912, 512])
# X_interme_dec:  torch.Size([960, 512])
# X_interme_dec:  torch.Size([960, 256])
# X_interme_dec:  torch.Size([966, 256])
# X_interme_dec:  torch.Size([966, 128])
# X_fin:  torch.Size([966, 128])
# X_fin:  torch.Size([966, 16])
# tensor([[ 2.8451, -0.1367, -0.0194,  ...,  3.6383,  3.1762,  3.1254],
#         [ 1.9106, -0.0610,  0.2159,  ...,  2.6141,  3.0736,  3.7869],
#         [ 2.1466, -0.0288,  0.1471,  ...,  2.1290,  3.2790,  3.8859],
#         ...,
#         [ 1.0645, -0.0840, -0.0505,  ...,  6.3956,  2.9979,  3.3150],
#         [ 0.8316, -0.2123,  0.4954,  ...,  1.8281,  3.9963, 10.9275],
#         [ 0.5605, -0.2410,  0.3519,  ...,  1.4769,  3.9589, 10.6034]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([966, 16])
# X_init:  5
# torch.Size([10532, 3])
# X_interme_enc:  torch.Size([10532, 64])
# X_interme_enc:  torch.Size([10532, 128])
# X_interme_enc:  torch.Size([5270, 128])
# X_interme_enc:  torch.Size([5270, 256])
# X_interme_enc:  torch.Size([5270, 256])
# X_interme_enc:  torch.Size([2103, 256])
# X_interme_enc:  torch.Size([2103, 512])
# X_interme_enc:  torch.Size([2103, 512])
# X_interme_enc:  torch.Size([818, 512])
# X_interme_enc:  torch.Size([818, 1024])
# X_interme_enc:  torch.Size([818, 1024])
# X_interme_enc:  torch.Size([233, 1024])
# X_interme_enc:  torch.Size([233, 2048])
# X_interme_dec:  torch.Size([818, 2048])
# X_interme_dec:  torch.Size([818, 1024])
# X_interme_dec:  torch.Size([2103, 1024])
# X_interme_dec:  torch.Size([2103, 512])
# X_interme_dec:  torch.Size([5270, 512])
# X_interme_dec:  torch.Size([5270, 256])
# X_interme_dec:  torch.Size([10532, 256])
# X_interme_dec:  torch.Size([10532, 128])
# X_fin:  torch.Size([10532, 128])
# X_fin:  torch.Size([10532, 16])
# tensor([[ 0.9032, -0.1990, -0.0550,  ..., 11.1013,  1.6403, -0.0315],
#         [ 0.7543, -0.1904, -0.0608,  ..., 10.7866,  1.5134, -0.0400],
#         [ 0.6565, -0.2015, -0.0705,  ...,  8.2609,  1.3725, -0.0939],
#         ...,
#         [ 0.6630, -0.1582, -0.0726,  ...,  7.7058,  1.5518,  0.2655],
#         [ 0.7074, -0.0922, -0.1244,  ...,  9.7964,  3.9375,  2.6480],
#         [ 0.1719, -0.2855, -0.1100,  ...,  5.2655,  2.4543,  1.9943]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10532, 16])
# X_init:  5
# torch.Size([4910, 3])
# X_interme_enc:  torch.Size([4910, 64])
# X_interme_enc:  torch.Size([4910, 128])
# X_interme_enc:  torch.Size([3817, 128])
# X_interme_enc:  torch.Size([3817, 256])
# X_interme_enc:  torch.Size([3817, 256])
# X_interme_enc:  torch.Size([2179, 256])
# X_interme_enc:  torch.Size([2179, 512])
# X_interme_enc:  torch.Size([2179, 512])
# X_interme_enc:  torch.Size([1020, 512])
# X_interme_enc:  torch.Size([1020, 1024])
# X_interme_enc:  torch.Size([1020, 1024])
# X_interme_enc:  torch.Size([397, 1024])
# X_interme_enc:  torch.Size([397, 2048])
# X_interme_dec:  torch.Size([1020, 2048])
# X_interme_dec:  torch.Size([1020, 1024])
# X_interme_dec:  torch.Size([2179, 1024])
# X_interme_dec:  torch.Size([2179, 512])
# X_interme_dec:  torch.Size([3817, 512])
# X_interme_dec:  torch.Size([3817, 256])
# X_interme_dec:  torch.Size([4910, 256])
# X_interme_dec:  torch.Size([4910, 128])
# X_fin:  torch.Size([4910, 128])
# X_fin:  torch.Size([4910, 16])
# tensor([[-0.0541, -0.2520, -0.0532,  ...,  4.7724,  1.0651, -0.0220],
#         [-0.0616, -0.2566, -0.0616,  ...,  5.0911,  1.0512, -0.0318],
#         [-0.0792, -0.2352, -0.0549,  ...,  4.6276,  0.9852, -0.0112],
#         ...,
#         [ 1.8277, -0.0953,  2.5039,  ...,  1.6830,  4.6657,  4.2801],
#         [ 1.9805,  0.0235,  2.2830,  ...,  1.1461,  3.8734,  1.6801],
#         [ 1.5421, -0.1361,  2.0600,  ...,  1.6607,  4.7510,  4.5433]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([4910, 16])
# X_init:  5
# torch.Size([2443, 3])
# X_interme_enc:  torch.Size([2443, 64])
# X_interme_enc:  torch.Size([2443, 128])
# X_interme_enc:  torch.Size([2340, 128])
# X_interme_enc:  torch.Size([2340, 256])
# X_interme_enc:  torch.Size([2340, 256])
# X_interme_enc:  torch.Size([1765, 256])
# X_interme_enc:  torch.Size([1765, 512])
# X_interme_enc:  torch.Size([1765, 512])
# X_interme_enc:  torch.Size([864, 512])
# X_interme_enc:  torch.Size([864, 1024])
# X_interme_enc:  torch.Size([864, 1024])
# X_interme_enc:  torch.Size([362, 1024])
# X_interme_enc:  torch.Size([362, 2048])
# X_interme_dec:  torch.Size([864, 2048])
# X_interme_dec:  torch.Size([864, 1024])
# X_interme_dec:  torch.Size([1765, 1024])
# X_interme_dec:  torch.Size([1765, 512])
# X_interme_dec:  torch.Size([2340, 512])
# X_interme_dec:  torch.Size([2340, 256])
# X_interme_dec:  torch.Size([2443, 256])
# X_interme_dec:  torch.Size([2443, 128])
# X_fin:  torch.Size([2443, 128])
# X_fin:  torch.Size([2443, 16])
# tensor([[ 1.4779,  0.9208, -0.0649,  ..., 10.0414,  9.4828,  3.4437],
#         [ 1.2737,  0.5928, -0.1175,  ...,  9.8105,  8.1341,  3.1735],
#         [ 0.9480,  0.8933, -0.1052,  ...,  9.7477,  7.2639,  3.1239],
#         ...,
#         [ 2.6483,  0.2275, -0.0573,  ..., 12.3452,  5.8864,  3.1274],
#         [ 2.9886,  0.2666, -0.0887,  ..., 11.9847,  5.6822,  3.4310],
#         [ 4.0054, -0.0129, -0.1126,  ..., 10.3527,  6.3820,  2.8039]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([2443, 16])
# X_init:  5
# torch.Size([1696, 3])
# X_interme_enc:  torch.Size([1696, 64])
# X_interme_enc:  torch.Size([1696, 128])
# X_interme_enc:  torch.Size([1686, 128])
# X_interme_enc:  torch.Size([1686, 256])
# X_interme_enc:  torch.Size([1686, 256])
# X_interme_enc:  torch.Size([1549, 256])
# X_interme_enc:  torch.Size([1549, 512])
# X_interme_enc:  torch.Size([1549, 512])
# X_interme_enc:  torch.Size([1080, 512])
# X_interme_enc:  torch.Size([1080, 1024])
# X_interme_enc:  torch.Size([1080, 1024])
# X_interme_enc:  torch.Size([615, 1024])
# X_interme_enc:  torch.Size([615, 2048])
# X_interme_dec:  torch.Size([1080, 2048])
# X_interme_dec:  torch.Size([1080, 1024])
# X_interme_dec:  torch.Size([1549, 1024])
# X_interme_dec:  torch.Size([1549, 512])
# X_interme_dec:  torch.Size([1686, 512])
# X_interme_dec:  torch.Size([1686, 256])
# X_interme_dec:  torch.Size([1696, 256])
# X_interme_dec:  torch.Size([1696, 128])
# X_fin:  torch.Size([1696, 128])
# X_fin:  torch.Size([1696, 16])
# tensor([[ 9.7197e-01, -4.0642e-01, -1.4664e-03,  ...,  4.6171e+00,
#           3.9579e+00, -2.0562e-02],
#         [-4.4994e-02, -2.6560e-01,  1.3254e-01,  ...,  4.9220e+00,
#           2.8773e+00,  9.6440e-02],
#         [-4.5646e-02, -2.8374e-01,  1.2473e-01,  ...,  5.1339e+00,
#           2.9693e+00,  1.8677e-01],
#         ...,
#         [ 6.7100e-01,  4.1814e-02,  2.6396e-01,  ...,  3.5427e+00,
#           6.8985e+00,  9.6250e+00],
#         [ 9.5927e-01, -1.5389e-02,  3.4361e-01,  ...,  3.2065e+00,
#           6.8608e+00,  9.2363e+00],
#         [ 1.9358e+00,  3.8574e-01, -3.6026e-02,  ...,  3.6839e+00,
#           6.9018e+00,  9.2544e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([1696, 16])
# X_init:  5
# torch.Size([5790, 3])
# X_interme_enc:  torch.Size([5790, 64])
# X_interme_enc:  torch.Size([5790, 128])
# X_interme_enc:  torch.Size([3956, 128])
# X_interme_enc:  torch.Size([3956, 256])
# X_interme_enc:  torch.Size([3956, 256])
# X_interme_enc:  torch.Size([2304, 256])
# X_interme_enc:  torch.Size([2304, 512])
# X_interme_enc:  torch.Size([2304, 512])
# X_interme_enc:  torch.Size([1141, 512])
# X_interme_enc:  torch.Size([1141, 1024])
# X_interme_enc:  torch.Size([1141, 1024])
# X_interme_enc:  torch.Size([498, 1024])
# X_interme_enc:  torch.Size([498, 2048])
# X_interme_dec:  torch.Size([1141, 2048])
# X_interme_dec:  torch.Size([1141, 1024])
# X_interme_dec:  torch.Size([2304, 1024])
# X_interme_dec:  torch.Size([2304, 512])
# X_interme_dec:  torch.Size([3956, 512])
# X_interme_dec:  torch.Size([3956, 256])
# X_interme_dec:  torch.Size([5790, 256])
# X_interme_dec:  torch.Size([5790, 128])
# X_fin:  torch.Size([5790, 128])
# X_fin:  torch.Size([5790, 16])
# tensor([[ 1.0162e+00, -3.1039e-01, -7.8344e-03,  ...,  6.1790e+00,
#           3.6981e+00, -8.6617e-02],
#         [ 8.1843e-01, -3.0255e-01, -6.3723e-03,  ...,  6.1901e+00,
#           3.5973e+00, -8.2533e-02],
#         [ 5.1017e-01, -2.5666e-01,  1.0408e-01,  ...,  5.7184e+00,
#           3.8393e+00, -1.0218e-01],
#         ...,
#         [-6.8573e-02, -2.0941e-01,  4.7250e-01,  ...,  4.7491e+00,
#           3.1827e+00,  5.7555e-01],
#         [-3.9817e-03, -9.5764e-02, -1.1801e-01,  ...,  6.3382e+00,
#           2.9698e+00,  1.8583e+00],
#         [ 2.6220e-02, -9.3758e-02, -1.2316e-01,  ...,  6.1437e+00,
#           2.7422e+00,  2.0804e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([5790, 16])
# X_init:  5
# torch.Size([1555, 3])
# X_interme_enc:  torch.Size([1555, 64])
# X_interme_enc:  torch.Size([1555, 128])
# X_interme_enc:  torch.Size([1528, 128])
# X_interme_enc:  torch.Size([1528, 256])
# X_interme_enc:  torch.Size([1528, 256])
# X_interme_enc:  torch.Size([1261, 256])
# X_interme_enc:  torch.Size([1261, 512])
# X_interme_enc:  torch.Size([1261, 512])
# X_interme_enc:  torch.Size([799, 512])
# X_interme_enc:  torch.Size([799, 1024])
# X_interme_enc:  torch.Size([799, 1024])
# X_interme_enc:  torch.Size([442, 1024])
# X_interme_enc:  torch.Size([442, 2048])
# X_interme_dec:  torch.Size([799, 2048])
# X_interme_dec:  torch.Size([799, 1024])
# X_interme_dec:  torch.Size([1261, 1024])
# X_interme_dec:  torch.Size([1261, 512])
# X_interme_dec:  torch.Size([1528, 512])
# X_interme_dec:  torch.Size([1528, 256])
# X_interme_dec:  torch.Size([1555, 256])
# X_interme_dec:  torch.Size([1555, 128])
# X_fin:  torch.Size([1555, 128])
# X_fin:  torch.Size([1555, 16])
# tensor([[ 7.6089e-01, -4.1090e-03, -3.1857e-02,  ...,  4.2113e+00,
#           2.3265e+00,  3.4153e+00],
#         [ 2.3679e+00,  5.1487e-01,  2.1710e+00,  ...,  1.0254e+00,
#           5.1979e+00,  3.7670e+00],
#         [ 3.3305e+00,  6.4307e-02,  1.8451e+00,  ...,  6.9606e-01,
#           5.3152e+00,  4.0504e+00],
#         ...,
#         [ 1.9912e+00,  7.8600e-01,  2.5049e-01,  ...,  1.2766e+00,
#           3.4259e+00,  1.2078e+00],
#         [ 2.2602e+00, -1.6502e-02,  1.6966e+00,  ...,  1.5237e-01,
#           8.7088e+00,  5.6874e+00],
#         [ 1.0658e+01, -3.2764e-01,  2.3073e-01,  ...,  1.0377e+00,
#           4.6057e+00,  3.9886e-01]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([1555, 16])
# X_init:  5
# torch.Size([10569, 3])
# X_interme_enc:  torch.Size([10569, 64])
# X_interme_enc:  torch.Size([10569, 128])
# X_interme_enc:  torch.Size([5562, 128])
# X_interme_enc:  torch.Size([5562, 256])
# X_interme_enc:  torch.Size([5562, 256])
# X_interme_enc:  torch.Size([2240, 256])
# X_interme_enc:  torch.Size([2240, 512])
# X_interme_enc:  torch.Size([2240, 512])
# X_interme_enc:  torch.Size([790, 512])
# X_interme_enc:  torch.Size([790, 1024])
# X_interme_enc:  torch.Size([790, 1024])
# X_interme_enc:  torch.Size([269, 1024])
# X_interme_enc:  torch.Size([269, 2048])
# X_interme_dec:  torch.Size([790, 2048])
# X_interme_dec:  torch.Size([790, 1024])
# X_interme_dec:  torch.Size([2240, 1024])
# X_interme_dec:  torch.Size([2240, 512])
# X_interme_dec:  torch.Size([5562, 512])
# X_interme_dec:  torch.Size([5562, 256])
# X_interme_dec:  torch.Size([10569, 256])
# X_interme_dec:  torch.Size([10569, 128])
# X_fin:  torch.Size([10569, 128])
# X_fin:  torch.Size([10569, 16])
# tensor([[-0.0502, -0.0684, -0.1270,  ...,  9.3524,  2.1893,  3.2364],
#         [-0.0516, -0.0909, -0.1077,  ...,  8.7825,  2.1725,  3.2106],
#         [-0.0526, -0.0755, -0.1057,  ...,  8.6414,  2.1740,  3.1084],
#         ...,
#         [ 2.5531, -0.0363, -0.1264,  ..., 14.9449,  4.2526,  5.2854],
#         [ 0.3900, -0.0154, -0.1487,  ...,  8.4835,  2.0823,  3.0809],
#         [ 2.7516, -0.0299, -0.1000,  ..., 12.9737,  3.8749,  2.3704]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10569, 16])
# X_init:  5
# torch.Size([9449, 3])
# X_interme_enc:  torch.Size([9449, 64])
# X_interme_enc:  torch.Size([9449, 128])
# X_interme_enc:  torch.Size([4922, 128])
# X_interme_enc:  torch.Size([4922, 256])
# X_interme_enc:  torch.Size([4922, 256])
# X_interme_enc:  torch.Size([2176, 256])
# X_interme_enc:  torch.Size([2176, 512])
# X_interme_enc:  torch.Size([2176, 512])
# X_interme_enc:  torch.Size([767, 512])
# X_interme_enc:  torch.Size([767, 1024])
# X_interme_enc:  torch.Size([767, 1024])
# X_interme_enc:  torch.Size([229, 1024])
# X_interme_enc:  torch.Size([229, 2048])
# X_interme_dec:  torch.Size([767, 2048])
# X_interme_dec:  torch.Size([767, 1024])
# X_interme_dec:  torch.Size([2176, 1024])
# X_interme_dec:  torch.Size([2176, 512])
# X_interme_dec:  torch.Size([4922, 512])
# X_interme_dec:  torch.Size([4922, 256])
# X_interme_dec:  torch.Size([9449, 256])
# X_interme_dec:  torch.Size([9449, 128])
# X_fin:  torch.Size([9449, 128])
# X_fin:  torch.Size([9449, 16])
# tensor([[ 0.3594, -0.2107,  1.2379,  ..., 10.7039,  1.5872, -0.1283],
#         [ 0.7880, -0.2090,  0.5741,  ..., 11.3181,  1.0847, -0.1393],
#         [ 0.5251, -0.1953,  0.6026,  ..., 11.1533,  1.0256, -0.1523],
#         ...,
#         [-0.0559, -0.2110,  0.2690,  ..., 10.5203,  3.0811,  1.1125],
#         [ 0.7878, -0.1144, -0.1683,  ..., 12.9082,  4.5785,  8.1516],
#         [ 0.6873, -0.0144, -0.1784,  ..., 10.5928,  4.7951, 10.8223]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([9449, 16])
# X_init:  5
# torch.Size([10461, 3])
# X_interme_enc:  torch.Size([10461, 64])
# X_interme_enc:  torch.Size([10461, 128])
# X_interme_enc:  torch.Size([4704, 128])
# X_interme_enc:  torch.Size([4704, 256])
# X_interme_enc:  torch.Size([4704, 256])
# X_interme_enc:  torch.Size([1949, 256])
# X_interme_enc:  torch.Size([1949, 512])
# X_interme_enc:  torch.Size([1949, 512])
# X_interme_enc:  torch.Size([673, 512])
# X_interme_enc:  torch.Size([673, 1024])
# X_interme_enc:  torch.Size([673, 1024])
# X_interme_enc:  torch.Size([233, 1024])
# X_interme_enc:  torch.Size([233, 2048])
# X_interme_dec:  torch.Size([673, 2048])
# X_interme_dec:  torch.Size([673, 1024])
# X_interme_dec:  torch.Size([1949, 1024])
# X_interme_dec:  torch.Size([1949, 512])
# X_interme_dec:  torch.Size([4704, 512])
# X_interme_dec:  torch.Size([4704, 256])
# X_interme_dec:  torch.Size([10461, 256])
# X_interme_dec:  torch.Size([10461, 128])
# X_fin:  torch.Size([10461, 128])
# X_fin:  torch.Size([10461, 16])
# tensor([[ 1.2938, -0.1931, -0.1215,  ..., 14.4761,  1.7234,  0.4853],
#         [ 1.3575, -0.2037, -0.1403,  ..., 14.5603,  1.8454,  0.4686],
#         [ 2.3928, -0.2459, -0.1285,  ..., 12.9597,  2.0111,  0.1248],
#         ...,
#         [ 0.7138, -0.2081, -0.1217,  ..., 12.4253,  1.4896, -0.0826],
#         [ 0.8454,  0.5590,  3.6282,  ...,  2.6091, 12.0634,  9.7373],
#         [ 0.5549, -0.1956, -0.1063,  ..., 12.1208,  1.2337, -0.1146]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10461, 16])
# X_init:  5
# torch.Size([9144, 3])
# X_interme_enc:  torch.Size([9144, 64])
# X_interme_enc:  torch.Size([9144, 128])
# X_interme_enc:  torch.Size([6839, 128])
# X_interme_enc:  torch.Size([6839, 256])
# X_interme_enc:  torch.Size([6839, 256])
# X_interme_enc:  torch.Size([3909, 256])
# X_interme_enc:  torch.Size([3909, 512])
# X_interme_enc:  torch.Size([3909, 512])
# X_interme_enc:  torch.Size([1671, 512])
# X_interme_enc:  torch.Size([1671, 1024])
# X_interme_enc:  torch.Size([1671, 1024])
# X_interme_enc:  torch.Size([626, 1024])
# X_interme_enc:  torch.Size([626, 2048])
# X_interme_dec:  torch.Size([1671, 2048])
# X_interme_dec:  torch.Size([1671, 1024])
# X_interme_dec:  torch.Size([3909, 1024])
# X_interme_dec:  torch.Size([3909, 512])
# X_interme_dec:  torch.Size([6839, 512])
# X_interme_dec:  torch.Size([6839, 256])
# X_interme_dec:  torch.Size([9144, 256])
# X_interme_dec:  torch.Size([9144, 128])
# X_fin:  torch.Size([9144, 128])
# X_fin:  torch.Size([9144, 16])
# tensor([[ 0.5605, -0.0490, -0.0357,  ..., 12.3985,  4.1228,  2.6687],
#         [ 0.4550, -0.0423, -0.0372,  ..., 13.3642,  4.4736,  2.7292],
#         [ 0.3251, -0.0608, -0.0362,  ..., 13.4450,  4.3757,  2.6411],
#         ...,
#         [ 2.8599,  0.4904, -0.0983,  ..., 13.5207,  4.4623,  6.1639],
#         [ 1.0785, -0.0826,  0.2373,  ..., 12.6691,  3.8755,  3.7624],
#         [ 1.0714,  0.7200,  1.4484,  ...,  7.4091,  8.5716, 10.2723]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([9144, 16])
# X_init:  5
# torch.Size([10746, 3])
# X_interme_enc:  torch.Size([10746, 64])
# X_interme_enc:  torch.Size([10746, 128])
# X_interme_enc:  torch.Size([5298, 128])
# X_interme_enc:  torch.Size([5298, 256])
# X_interme_enc:  torch.Size([5298, 256])
# X_interme_enc:  torch.Size([2261, 256])
# X_interme_enc:  torch.Size([2261, 512])
# X_interme_enc:  torch.Size([2261, 512])
# X_interme_enc:  torch.Size([836, 512])
# X_interme_enc:  torch.Size([836, 1024])
# X_interme_enc:  torch.Size([836, 1024])
# X_interme_enc:  torch.Size([259, 1024])
# X_interme_enc:  torch.Size([259, 2048])
# X_interme_dec:  torch.Size([836, 2048])
# X_interme_dec:  torch.Size([836, 1024])
# X_interme_dec:  torch.Size([2261, 1024])
# X_interme_dec:  torch.Size([2261, 512])
# X_interme_dec:  torch.Size([5298, 512])
# X_interme_dec:  torch.Size([5298, 256])
# X_interme_dec:  torch.Size([10746, 256])
# X_interme_dec:  torch.Size([10746, 128])
# X_fin:  torch.Size([10746, 128])
# X_fin:  torch.Size([10746, 16])
# tensor([[ 1.3024, -0.0195, -0.0733,  ..., 12.7564,  3.5150,  1.9374],
#         [ 0.9738, -0.0219, -0.0470,  ..., 13.2193,  3.4460,  2.0442],
#         [ 1.3599, -0.0549, -0.0531,  ..., 12.7952,  3.4546,  2.0044],
#         ...,
#         [ 1.6398, -0.0388,  1.5051,  ...,  3.0846,  6.3955, 14.4916],
#         [ 0.1261, -0.2153,  0.7256,  ...,  3.9084,  3.7742,  0.8541],
#         [ 2.1186, -0.1722,  1.8476,  ...,  3.0491,  6.3167, 14.1777]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10746, 16])
# X_init:  5
# torch.Size([12556, 3])
# X_interme_enc:  torch.Size([12556, 64])
# X_interme_enc:  torch.Size([12556, 128])
# X_interme_enc:  torch.Size([9049, 128])
# X_interme_enc:  torch.Size([9049, 256])
# X_interme_enc:  torch.Size([9049, 256])
# X_interme_enc:  torch.Size([4512, 256])
# X_interme_enc:  torch.Size([4512, 512])
# X_interme_enc:  torch.Size([4512, 512])
# X_interme_enc:  torch.Size([1662, 512])
# X_interme_enc:  torch.Size([1662, 1024])
# X_interme_enc:  torch.Size([1662, 1024])
# X_interme_enc:  torch.Size([524, 1024])
# X_interme_enc:  torch.Size([524, 2048])
# X_interme_dec:  torch.Size([1662, 2048])
# X_interme_dec:  torch.Size([1662, 1024])
# X_interme_dec:  torch.Size([4512, 1024])
# X_interme_dec:  torch.Size([4512, 512])
# X_interme_dec:  torch.Size([9049, 512])
# X_interme_dec:  torch.Size([9049, 256])
# X_interme_dec:  torch.Size([12556, 256])
# X_interme_dec:  torch.Size([12556, 128])
# X_fin:  torch.Size([12556, 128])
# X_fin:  torch.Size([12556, 16])
# tensor([[ 1.7115e+00,  2.4834e+00,  9.4469e-02,  ...,  1.1442e+01,
#           1.7548e+00,  4.1261e+00],
#         [ 1.1219e+00,  7.3868e-01, -7.3678e-03,  ...,  1.2398e+01,
#           2.0133e+00,  3.5384e+00],
#         [ 1.6797e+00,  6.3488e-01, -2.5039e-02,  ...,  1.2099e+01,
#           2.0922e+00,  3.5174e+00],
#         ...,
#         [ 8.6024e-01, -8.5608e-02,  2.2586e-01,  ...,  3.0530e+00,
#           5.5304e+00,  1.1628e+01],
#         [-5.3165e-02,  7.5821e-02, -3.4872e-02,  ...,  5.3786e+00,
#           2.9614e+00,  8.1697e+00],
#         [-5.1848e-02,  4.4096e-01, -6.3244e-02,  ...,  4.3497e+00,
#           4.9747e+00,  1.2197e+01]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([12556, 16])
# X_init:  5
# torch.Size([6953, 3])
# X_interme_enc:  torch.Size([6953, 64])
# X_interme_enc:  torch.Size([6953, 128])
# X_interme_enc:  torch.Size([5252, 128])
# X_interme_enc:  torch.Size([5252, 256])
# X_interme_enc:  torch.Size([5252, 256])
# X_interme_enc:  torch.Size([3096, 256])
# X_interme_enc:  torch.Size([3096, 512])
# X_interme_enc:  torch.Size([3096, 512])
# X_interme_enc:  torch.Size([1341, 512])
# X_interme_enc:  torch.Size([1341, 1024])
# X_interme_enc:  torch.Size([1341, 1024])
# X_interme_enc:  torch.Size([502, 1024])
# X_interme_enc:  torch.Size([502, 2048])
# X_interme_dec:  torch.Size([1341, 2048])
# X_interme_dec:  torch.Size([1341, 1024])
# X_interme_dec:  torch.Size([3096, 1024])
# X_interme_dec:  torch.Size([3096, 512])
# X_interme_dec:  torch.Size([5252, 512])
# X_interme_dec:  torch.Size([5252, 256])
# X_interme_dec:  torch.Size([6953, 256])
# X_interme_dec:  torch.Size([6953, 128])
# X_fin:  torch.Size([6953, 128])
# X_fin:  torch.Size([6953, 16])
# tensor([[ 9.7891e-01, -4.8332e-02,  1.9343e-01,  ...,  3.7751e+00,
#           4.4654e+00,  1.0902e+01],
#         [ 9.2082e-01, -1.4202e-02,  1.2581e+00,  ...,  3.3209e+00,
#           3.0335e+00,  1.0420e+01],
#         [ 1.0965e+00, -1.6514e-02,  9.1139e-01,  ...,  3.5466e+00,
#           3.3921e+00,  1.0978e+01],
#         ...,
#         [ 2.3497e+00, -5.0930e-02, -1.9647e-01,  ...,  1.0562e+01,
#           4.7542e+00,  7.5963e+00],
#         [ 2.7538e+00,  1.0537e+00, -4.2384e-02,  ...,  8.9814e+00,
#           6.9785e+00,  8.4468e+00],
#         [ 2.3920e+00,  1.0588e+00, -1.0476e-02,  ...,  8.9565e+00,
#           6.5062e+00,  8.4541e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([6953, 16])
# X_init:  5
# torch.Size([3214, 3])
# X_interme_enc:  torch.Size([3214, 64])
# X_interme_enc:  torch.Size([3214, 128])
# X_interme_enc:  torch.Size([2887, 128])
# X_interme_enc:  torch.Size([2887, 256])
# X_interme_enc:  torch.Size([2887, 256])
# X_interme_enc:  torch.Size([1859, 256])
# X_interme_enc:  torch.Size([1859, 512])
# X_interme_enc:  torch.Size([1859, 512])
# X_interme_enc:  torch.Size([926, 512])
# X_interme_enc:  torch.Size([926, 1024])
# X_interme_enc:  torch.Size([926, 1024])
# X_interme_enc:  torch.Size([390, 1024])
# X_interme_enc:  torch.Size([390, 2048])
# X_interme_dec:  torch.Size([926, 2048])
# X_interme_dec:  torch.Size([926, 1024])
# X_interme_dec:  torch.Size([1859, 1024])
# X_interme_dec:  torch.Size([1859, 512])
# X_interme_dec:  torch.Size([2887, 512])
# X_interme_dec:  torch.Size([2887, 256])
# X_interme_dec:  torch.Size([3214, 256])
# X_interme_dec:  torch.Size([3214, 128])
# X_fin:  torch.Size([3214, 128])
# X_fin:  torch.Size([3214, 16])
# tensor([[ 1.4195e+00, -2.0145e-01, -3.8396e-02,  ...,  4.9860e+00,
#           3.7922e+00,  7.1664e-01],
#         [ 1.0151e+00, -2.2077e-01, -3.5419e-02,  ...,  5.8143e+00,
#           3.8320e+00,  7.1287e-01],
#         [ 4.4988e-01, -2.0486e-01, -2.9585e-02,  ...,  5.6726e+00,
#           3.5885e+00,  5.9617e-01],
#         ...,
#         [-4.3802e-02, -1.4765e-01, -1.6764e-02,  ...,  8.2488e+00,
#           3.0227e+00,  1.1485e+00],
#         [ 1.7811e+00, -8.0904e-02,  8.7605e-01,  ...,  1.3758e+00,
#           5.0764e+00,  7.1120e+00],
#         [-4.5837e-02, -1.6181e-01, -4.0092e-03,  ...,  7.5604e+00,
#           3.7120e+00,  1.5715e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([3214, 16])
# X_init:  5
# torch.Size([2972, 3])
# X_interme_enc:  torch.Size([2972, 64])
# X_interme_enc:  torch.Size([2972, 128])
# X_interme_enc:  torch.Size([2812, 128])
# X_interme_enc:  torch.Size([2812, 256])
# X_interme_enc:  torch.Size([2812, 256])
# X_interme_enc:  torch.Size([2195, 256])
# X_interme_enc:  torch.Size([2195, 512])
# X_interme_enc:  torch.Size([2195, 512])
# X_interme_enc:  torch.Size([1300, 512])
# X_interme_enc:  torch.Size([1300, 1024])
# X_interme_enc:  torch.Size([1300, 1024])
# X_interme_enc:  torch.Size([638, 1024])
# X_interme_enc:  torch.Size([638, 2048])
# X_interme_dec:  torch.Size([1300, 2048])
# X_interme_dec:  torch.Size([1300, 1024])
# X_interme_dec:  torch.Size([2195, 1024])
# X_interme_dec:  torch.Size([2195, 512])
# X_interme_dec:  torch.Size([2812, 512])
# X_interme_dec:  torch.Size([2812, 256])
# X_interme_dec:  torch.Size([2972, 256])
# X_interme_dec:  torch.Size([2972, 128])
# X_fin:  torch.Size([2972, 128])
# X_fin:  torch.Size([2972, 16])
# tensor([[-5.8878e-03,  1.5155e-01, -4.4892e-02,  ...,  8.9364e+00,
#           2.8197e+00,  3.5472e+00],
#         [-3.9849e-02, -2.9225e-02, -3.9823e-02,  ...,  9.7153e+00,
#           3.0339e+00,  3.4716e+00],
#         [-1.8261e-02, -4.6823e-02, -4.1515e-02,  ...,  9.4226e+00,
#           3.0837e+00,  3.4596e+00],
#         ...,
#         [ 1.5927e-02, -5.2468e-02, -7.5369e-02,  ...,  9.9231e+00,
#           3.3655e+00,  3.0874e+00],
#         [-1.9748e-02, -2.4812e-02,  2.5144e-01,  ...,  1.1486e+01,
#           3.9929e+00,  2.4614e+00],
#         [ 1.7451e-01, -6.7216e-02, -5.3192e-02,  ...,  1.0335e+01,
#           3.6304e+00,  3.4906e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([2972, 16])
# X_init:  5
# torch.Size([1107, 3])
# X_interme_enc:  torch.Size([1107, 64])
# X_interme_enc:  torch.Size([1107, 128])
# X_interme_enc:  torch.Size([1104, 128])
# X_interme_enc:  torch.Size([1104, 256])
# X_interme_enc:  torch.Size([1104, 256])
# X_interme_enc:  torch.Size([1025, 256])
# X_interme_enc:  torch.Size([1025, 512])
# X_interme_enc:  torch.Size([1025, 512])
# X_interme_enc:  torch.Size([724, 512])
# X_interme_enc:  torch.Size([724, 1024])
# X_interme_enc:  torch.Size([724, 1024])
# X_interme_enc:  torch.Size([363, 1024])
# X_interme_enc:  torch.Size([363, 2048])
# X_interme_dec:  torch.Size([724, 2048])
# X_interme_dec:  torch.Size([724, 1024])
# X_interme_dec:  torch.Size([1025, 1024])
# X_interme_dec:  torch.Size([1025, 512])
# X_interme_dec:  torch.Size([1104, 512])
# X_interme_dec:  torch.Size([1104, 256])
# X_interme_dec:  torch.Size([1107, 256])
# X_interme_dec:  torch.Size([1107, 128])
# X_fin:  torch.Size([1107, 128])
# X_fin:  torch.Size([1107, 16])
# tensor([[ 1.2244e+00, -1.4563e-01, -4.5668e-02,  ...,  4.8963e+00,
#           4.1398e+00,  3.4513e+00],
#         [-4.9162e-02, -2.7279e-02, -9.6789e-03,  ...,  5.6908e+00,
#           2.3914e+00,  1.5336e+00],
#         [-4.2654e-02, -2.2010e-02, -1.8401e-02,  ...,  5.6140e+00,
#           2.4240e+00,  1.4443e+00],
#         ...,
#         [ 1.4918e+00,  8.1107e-01, -1.2326e-01,  ...,  5.5768e+00,
#           4.5320e+00,  1.0898e+01],
#         [ 3.1736e-01, -9.7654e-02,  4.4174e-01,  ...,  2.5652e+00,
#           3.3029e+00,  1.2321e+01],
#         [ 2.3430e-01, -1.1834e-01, -1.6798e-02,  ...,  2.3597e+00,
#           2.9619e+00,  1.1743e+01]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([1107, 16])
# X_init:  5
# torch.Size([3605, 3])
# X_interme_enc:  torch.Size([3605, 64])
# X_interme_enc:  torch.Size([3605, 128])
# X_interme_enc:  torch.Size([3164, 128])
# X_interme_enc:  torch.Size([3164, 256])
# X_interme_enc:  torch.Size([3164, 256])
# X_interme_enc:  torch.Size([2111, 256])
# X_interme_enc:  torch.Size([2111, 512])
# X_interme_enc:  torch.Size([2111, 512])
# X_interme_enc:  torch.Size([1085, 512])
# X_interme_enc:  torch.Size([1085, 1024])
# X_interme_enc:  torch.Size([1085, 1024])
# X_interme_enc:  torch.Size([501, 1024])
# X_interme_enc:  torch.Size([501, 2048])
# X_interme_dec:  torch.Size([1085, 2048])
# X_interme_dec:  torch.Size([1085, 1024])
# X_interme_dec:  torch.Size([2111, 1024])
# X_interme_dec:  torch.Size([2111, 512])
# X_interme_dec:  torch.Size([3164, 512])
# X_interme_dec:  torch.Size([3164, 256])
# X_interme_dec:  torch.Size([3605, 256])
# X_interme_dec:  torch.Size([3605, 128])
# X_fin:  torch.Size([3605, 128])
# X_fin:  torch.Size([3605, 16])
# tensor([[ 3.3514,  0.2269, -0.1763,  ...,  5.1837,  7.1711,  3.8951],
#         [ 3.2976,  0.1478, -0.1880,  ...,  5.2852,  7.6936,  4.0461],
#         [ 3.7861,  0.1855, -0.1718,  ...,  4.1567,  7.1739,  3.8378],
#         ...,
#         [ 0.3010, -0.0348,  0.3288,  ...,  3.3271,  6.4474,  8.6298],
#         [ 0.5817, -0.1320,  0.6207,  ...,  3.7543,  4.6195,  1.5688],
#         [ 0.8321, -0.0314,  0.3673,  ...,  5.0749,  4.0267, 11.8906]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([3605, 16])
# X_init:  5
# torch.Size([5515, 3])
# X_interme_enc:  torch.Size([5515, 64])
# X_interme_enc:  torch.Size([5515, 128])
# X_interme_enc:  torch.Size([3864, 128])
# X_interme_enc:  torch.Size([3864, 256])
# X_interme_enc:  torch.Size([3864, 256])
# X_interme_enc:  torch.Size([2124, 256])
# X_interme_enc:  torch.Size([2124, 512])
# X_interme_enc:  torch.Size([2124, 512])
# X_interme_enc:  torch.Size([993, 512])
# X_interme_enc:  torch.Size([993, 1024])
# X_interme_enc:  torch.Size([993, 1024])
# X_interme_enc:  torch.Size([390, 1024])
# X_interme_enc:  torch.Size([390, 2048])
# X_interme_dec:  torch.Size([993, 2048])
# X_interme_dec:  torch.Size([993, 1024])
# X_interme_dec:  torch.Size([2124, 1024])
# X_interme_dec:  torch.Size([2124, 512])
# X_interme_dec:  torch.Size([3864, 512])
# X_interme_dec:  torch.Size([3864, 256])
# X_interme_dec:  torch.Size([5515, 256])
# X_interme_dec:  torch.Size([5515, 128])
# X_fin:  torch.Size([5515, 128])
# X_fin:  torch.Size([5515, 16])
# tensor([[-2.0321e-02, -1.0393e-01, -4.8362e-03,  ...,  3.4917e+00,
#           5.5403e+00,  1.0080e+01],
#         [ 1.4522e-01, -9.1681e-02,  1.2215e-01,  ...,  3.2794e+00,
#           5.8439e+00,  1.0539e+01],
#         [ 1.2031e-01, -6.3363e-02,  3.3783e-02,  ...,  3.4064e+00,
#           5.7855e+00,  1.0143e+01],
#         ...,
#         [ 4.8093e-01, -4.2701e-02, -1.7269e-01,  ...,  8.5723e+00,
#           3.7355e+00,  6.7926e+00],
#         [ 1.7911e+00, -1.1509e-01, -1.2453e-01,  ...,  1.1861e+01,
#           5.2086e+00,  2.8687e+00],
#         [ 2.1023e+00, -1.0447e-01, -1.2838e-01,  ...,  1.2042e+01,
#           4.7692e+00,  3.1965e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([5515, 16])
# X_init:  5
# torch.Size([3396, 3])
# X_interme_enc:  torch.Size([3396, 64])
# X_interme_enc:  torch.Size([3396, 128])
# X_interme_enc:  torch.Size([3234, 128])
# X_interme_enc:  torch.Size([3234, 256])
# X_interme_enc:  torch.Size([3234, 256])
# X_interme_enc:  torch.Size([2626, 256])
# X_interme_enc:  torch.Size([2626, 512])
# X_interme_enc:  torch.Size([2626, 512])
# X_interme_enc:  torch.Size([1614, 512])
# X_interme_enc:  torch.Size([1614, 1024])
# X_interme_enc:  torch.Size([1614, 1024])
# X_interme_enc:  torch.Size([795, 1024])
# X_interme_enc:  torch.Size([795, 2048])
# X_interme_dec:  torch.Size([1614, 2048])
# X_interme_dec:  torch.Size([1614, 1024])
# X_interme_dec:  torch.Size([2626, 1024])
# X_interme_dec:  torch.Size([2626, 512])
# X_interme_dec:  torch.Size([3234, 512])
# X_interme_dec:  torch.Size([3234, 256])
# X_interme_dec:  torch.Size([3396, 256])
# X_interme_dec:  torch.Size([3396, 128])
# X_fin:  torch.Size([3396, 128])
# X_fin:  torch.Size([3396, 16])
# tensor([[ 0.8495, -0.0448, -0.0373,  ...,  2.9536,  5.8787,  7.0999],
#         [ 0.5846, -0.0562, -0.0572,  ...,  3.1503,  5.4806,  6.8083],
#         [ 3.5067, -0.0524, -0.0158,  ...,  2.8530,  7.2808,  6.9165],
#         ...,
#         [-0.0703, -0.0879,  1.9260,  ...,  2.6890,  5.2212, 12.1495],
#         [-0.0651, -0.0768,  1.4946,  ...,  2.7700,  4.2677, 12.9170],
#         [-0.0397, -0.0962,  1.5939,  ...,  3.3163,  4.2456, 12.7659]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([3396, 16])
# Sequence: 08, subsample number 1/1:   0%|                                            | 1/4071 [00:06<7:30:24,  6.64s/it]
# X_init:  5
# torch.Size([10147, 3])
# X_interme_enc:  torch.Size([10147, 64])
# X_interme_enc:  torch.Size([10147, 128])
# X_interme_enc:  torch.Size([4684, 128])
# X_interme_enc:  torch.Size([4684, 256])
# X_interme_enc:  torch.Size([4684, 256])
# X_interme_enc:  torch.Size([2058, 256])
# X_interme_enc:  torch.Size([2058, 512])
# X_interme_enc:  torch.Size([2058, 512])
# X_interme_enc:  torch.Size([629, 512])
# X_interme_enc:  torch.Size([629, 1024])
# X_interme_enc:  torch.Size([629, 1024])
# X_interme_enc:  torch.Size([209, 1024])
# X_interme_enc:  torch.Size([209, 2048])
# X_interme_dec:  torch.Size([629, 2048])
# X_interme_dec:  torch.Size([629, 1024])
# X_interme_dec:  torch.Size([2058, 1024])
# X_interme_dec:  torch.Size([2058, 512])
# X_interme_dec:  torch.Size([4684, 512])
# X_interme_dec:  torch.Size([4684, 256])
# X_interme_dec:  torch.Size([10147, 256])
# X_interme_dec:  torch.Size([10147, 128])
# X_fin:  torch.Size([10147, 128])
# X_fin:  torch.Size([10147, 16])
# tensor([[-2.7562e-02, -1.8232e-01, -1.6487e-02,  ...,  3.3248e+00,
#           1.6106e+00,  5.8938e-01],
#         [-1.9824e-02, -1.9822e-01,  1.2725e-01,  ...,  3.0805e+00,
#           1.3622e+00, -9.8814e-03],
#         [-1.8085e-02, -1.9410e-01,  9.4713e-02,  ...,  2.9681e+00,
#           1.3567e+00, -5.2171e-03],
#         ...,
#         [-7.9823e-02, -2.0845e-01, -4.5194e-02,  ...,  5.1747e+00,
#           1.6497e+00,  4.9427e-01],
#         [ 6.7753e-01, -2.5595e-01, -9.8176e-02,  ...,  3.7671e+00,
#           3.3907e-01,  7.5111e-01],
#         [ 6.3883e-01, -3.7674e-02, -9.6364e-02,  ...,  9.3401e+00,
#           3.8592e+00,  7.7187e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10147, 16])
# X_init:  5
# torch.Size([8786, 3])
# X_interme_enc:  torch.Size([8786, 64])
# X_interme_enc:  torch.Size([8786, 128])
# X_interme_enc:  torch.Size([6754, 128])
# X_interme_enc:  torch.Size([6754, 256])
# X_interme_enc:  torch.Size([6754, 256])
# X_interme_enc:  torch.Size([3810, 256])
# X_interme_enc:  torch.Size([3810, 512])
# X_interme_enc:  torch.Size([3810, 512])
# X_interme_enc:  torch.Size([1695, 512])
# X_interme_enc:  torch.Size([1695, 1024])
# X_interme_enc:  torch.Size([1695, 1024])
# X_interme_enc:  torch.Size([667, 1024])
# X_interme_enc:  torch.Size([667, 2048])
# X_interme_dec:  torch.Size([1695, 2048])
# X_interme_dec:  torch.Size([1695, 1024])
# X_interme_dec:  torch.Size([3810, 1024])
# X_interme_dec:  torch.Size([3810, 512])
# X_interme_dec:  torch.Size([6754, 512])
# X_interme_dec:  torch.Size([6754, 256])
# X_interme_dec:  torch.Size([8786, 256])
# X_interme_dec:  torch.Size([8786, 128])
# X_fin:  torch.Size([8786, 128])
# X_fin:  torch.Size([8786, 16])
# tensor([[ 0.9191,  2.0127,  0.5849,  ..., 12.3517,  3.0439,  3.2779],
#         [ 0.0899,  1.7234,  0.9849,  ..., 12.4492,  3.1089,  3.2888],
#         [ 0.0475,  2.8207,  1.5287,  ..., 12.6467,  2.8425,  2.8813],
#         ...,
#         [ 0.5245, -0.0311,  0.0746,  ..., 12.6563,  4.1397,  4.6654],
#         [ 0.1119,  1.0833,  1.8818,  ...,  6.7133,  5.9405, 11.7678],
#         [ 1.6449, -0.0262,  3.6495,  ...,  3.3657,  4.8623, 13.6513]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([8786, 16])
# X_init:  5
# torch.Size([11586, 3])
# X_interme_enc:  torch.Size([11586, 64])
# X_interme_enc:  torch.Size([11586, 128])
# X_interme_enc:  torch.Size([8487, 128])
# X_interme_enc:  torch.Size([8487, 256])
# X_interme_enc:  torch.Size([8487, 256])
# X_interme_enc:  torch.Size([4189, 256])
# X_interme_enc:  torch.Size([4189, 512])
# X_interme_enc:  torch.Size([4189, 512])
# X_interme_enc:  torch.Size([1617, 512])
# X_interme_enc:  torch.Size([1617, 1024])
# X_interme_enc:  torch.Size([1617, 1024])
# X_interme_enc:  torch.Size([526, 1024])
# X_interme_enc:  torch.Size([526, 2048])
# X_interme_dec:  torch.Size([1617, 2048])
# X_interme_dec:  torch.Size([1617, 1024])
# X_interme_dec:  torch.Size([4189, 1024])
# X_interme_dec:  torch.Size([4189, 512])
# X_interme_dec:  torch.Size([8487, 512])
# X_interme_dec:  torch.Size([8487, 256])
# X_interme_dec:  torch.Size([11586, 256])
# X_interme_dec:  torch.Size([11586, 128])
# X_fin:  torch.Size([11586, 128])
# X_fin:  torch.Size([11586, 16])
# tensor([[ 8.8392e-01, -1.2627e-01, -5.2437e-02,  ...,  1.2217e+01,
#           4.6991e+00,  3.2368e+00],
#         [ 8.7439e-01, -1.3521e-01, -3.4578e-02,  ...,  1.1627e+01,
#           4.6336e+00,  2.8935e+00],
#         [ 1.6737e-01, -8.0612e-02, -1.6885e-01,  ...,  8.3016e+00,
#           1.8704e+00,  3.6843e+00],
#         ...,
#         [ 9.9227e-01, -1.2134e-01, -3.3283e-02,  ...,  4.0906e+00,
#           4.6425e+00,  1.2307e+01],
#         [ 8.7484e-01, -4.5324e-03, -2.4537e-02,  ...,  2.8226e+00,
#           4.4808e+00,  1.2169e+01],
#         [ 1.8451e+00, -1.4562e-01,  6.6179e-01,  ...,  2.8614e+00,
#           4.1898e+00,  1.0675e+01]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([11586, 16])
# X_init:  5
# torch.Size([10820, 3])
# X_interme_enc:  torch.Size([10820, 64])
# X_interme_enc:  torch.Size([10820, 128])
# X_interme_enc:  torch.Size([4963, 128])
# X_interme_enc:  torch.Size([4963, 256])
# X_interme_enc:  torch.Size([4963, 256])
# X_interme_enc:  torch.Size([2031, 256])
# X_interme_enc:  torch.Size([2031, 512])
# X_interme_enc:  torch.Size([2031, 512])
# X_interme_enc:  torch.Size([736, 512])
# X_interme_enc:  torch.Size([736, 1024])
# X_interme_enc:  torch.Size([736, 1024])
# X_interme_enc:  torch.Size([232, 1024])
# X_interme_enc:  torch.Size([232, 2048])
# X_interme_dec:  torch.Size([736, 2048])
# X_interme_dec:  torch.Size([736, 1024])
# X_interme_dec:  torch.Size([2031, 1024])
# X_interme_dec:  torch.Size([2031, 512])
# X_interme_dec:  torch.Size([4963, 512])
# X_interme_dec:  torch.Size([4963, 256])
# X_interme_dec:  torch.Size([10820, 256])
# X_interme_dec:  torch.Size([10820, 128])
# X_fin:  torch.Size([10820, 128])
# X_fin:  torch.Size([10820, 16])
# tensor([[ 0.0839, -0.0481, -0.1444,  ..., 10.8549,  3.4951,  2.8028],
#         [ 0.0938, -0.0490, -0.1465,  ..., 10.9280,  3.5171,  2.8675],
#         [ 1.4744, -0.0754, -0.1382,  ..., 13.3711,  2.3702,  2.0456],
#         ...,
#         [ 1.1538, -0.2189, -0.1011,  ...,  9.9617,  2.6997,  1.4096],
#         [ 2.7925,  0.1094, -0.0518,  ..., 13.6337,  2.8715,  2.3011],
#         [ 1.3290, -0.2273, -0.0994,  ..., 10.1927,  2.8170,  1.4556]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10820, 16])
# X_init:  5
# torch.Size([1115, 3])
# X_interme_enc:  torch.Size([1115, 64])
# X_interme_enc:  torch.Size([1115, 128])
# X_interme_enc:  torch.Size([1106, 128])
# X_interme_enc:  torch.Size([1106, 256])
# X_interme_enc:  torch.Size([1106, 256])
# X_interme_enc:  torch.Size([1020, 256])
# X_interme_enc:  torch.Size([1020, 512])
# X_interme_enc:  torch.Size([1020, 512])
# X_interme_enc:  torch.Size([762, 512])
# X_interme_enc:  torch.Size([762, 1024])
# X_interme_enc:  torch.Size([762, 1024])
# X_interme_enc:  torch.Size([428, 1024])
# X_interme_enc:  torch.Size([428, 2048])
# X_interme_dec:  torch.Size([762, 2048])
# X_interme_dec:  torch.Size([762, 1024])
# X_interme_dec:  torch.Size([1020, 1024])
# X_interme_dec:  torch.Size([1020, 512])
# X_interme_dec:  torch.Size([1106, 512])
# X_interme_dec:  torch.Size([1106, 256])
# X_interme_dec:  torch.Size([1115, 256])
# X_interme_dec:  torch.Size([1115, 128])
# X_fin:  torch.Size([1115, 128])
# X_fin:  torch.Size([1115, 16])
# tensor([[ 4.6978, -0.1524,  2.0384,  ...,  0.0546,  6.9050,  4.1910],
#         [ 1.3356, -0.1955,  1.1994,  ...,  1.4879,  5.8759, 12.1298],
#         [ 1.8706, -0.1102, -0.1776,  ...,  5.0808,  3.4903,  7.8635],
#         ...,
#         [ 0.3073,  0.1001,  1.2086,  ...,  3.9612,  5.9284, 10.6007],
#         [-0.0444, -0.1429,  0.9800,  ...,  1.5513,  4.7158, 10.4523],
#         [-0.0840, -0.1392,  1.3040,  ...,  1.3152,  4.9711, 10.6517]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([1115, 16])
# X_init:  5
# torch.Size([1691, 3])
# X_interme_enc:  torch.Size([1691, 64])
# X_interme_enc:  torch.Size([1691, 128])
# X_interme_enc:  torch.Size([1682, 128])
# X_interme_enc:  torch.Size([1682, 256])
# X_interme_enc:  torch.Size([1682, 256])
# X_interme_enc:  torch.Size([1537, 256])
# X_interme_enc:  torch.Size([1537, 512])
# X_interme_enc:  torch.Size([1537, 512])
# X_interme_enc:  torch.Size([1103, 512])
# X_interme_enc:  torch.Size([1103, 1024])
# X_interme_enc:  torch.Size([1103, 1024])
# X_interme_enc:  torch.Size([620, 1024])
# X_interme_enc:  torch.Size([620, 2048])
# X_interme_dec:  torch.Size([1103, 2048])
# X_interme_dec:  torch.Size([1103, 1024])
# X_interme_dec:  torch.Size([1537, 1024])
# X_interme_dec:  torch.Size([1537, 512])
# X_interme_dec:  torch.Size([1682, 512])
# X_interme_dec:  torch.Size([1682, 256])
# X_interme_dec:  torch.Size([1691, 256])
# X_interme_dec:  torch.Size([1691, 128])
# X_fin:  torch.Size([1691, 128])
# X_fin:  torch.Size([1691, 16])
# tensor([[ 7.0283e-01, -2.3834e-01, -3.6268e-02,  ...,  6.1712e+00,
#           2.6895e+00,  1.1396e+00],
#         [ 7.6094e-01, -2.4886e-01, -4.4450e-02,  ...,  6.3535e+00,
#           2.8427e+00,  1.3824e+00],
#         [ 8.2913e-01, -2.6041e-01, -4.3315e-02,  ...,  6.0151e+00,
#           3.1284e+00,  8.4209e-01],
#         ...,
#         [ 2.8074e+00, -8.3416e-03,  7.1362e-04,  ...,  3.3138e-01,
#           8.0373e+00,  2.1913e+00],
#         [ 6.9906e+00, -2.3985e-01, -8.3873e-02,  ...,  2.0980e+00,
#           6.4613e+00,  2.3668e+00],
#         [ 6.4449e+00, -4.3076e-02, -6.7667e-02,  ...,  8.1171e-01,
#           8.5541e+00,  2.4975e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([1691, 16])
# X_init:  5
# torch.Size([6504, 3])
# X_interme_enc:  torch.Size([6504, 64])
# X_interme_enc:  torch.Size([6504, 128])
# X_interme_enc:  torch.Size([3828, 128])
# X_interme_enc:  torch.Size([3828, 256])
# X_interme_enc:  torch.Size([3828, 256])
# X_interme_enc:  torch.Size([1842, 256])
# X_interme_enc:  torch.Size([1842, 512])
# X_interme_enc:  torch.Size([1842, 512])
# X_interme_enc:  torch.Size([777, 512])
# X_interme_enc:  torch.Size([777, 1024])
# X_interme_enc:  torch.Size([777, 1024])
# X_interme_enc:  torch.Size([260, 1024])
# X_interme_enc:  torch.Size([260, 2048])
# X_interme_dec:  torch.Size([777, 2048])
# X_interme_dec:  torch.Size([777, 1024])
# X_interme_dec:  torch.Size([1842, 1024])
# X_interme_dec:  torch.Size([1842, 512])
# X_interme_dec:  torch.Size([3828, 512])
# X_interme_dec:  torch.Size([3828, 256])
# X_interme_dec:  torch.Size([6504, 256])
# X_interme_dec:  torch.Size([6504, 128])
# X_fin:  torch.Size([6504, 128])
# X_fin:  torch.Size([6504, 16])
# tensor([[ 5.8591e-03, -2.6444e-01, -1.0117e-01,  ...,  4.8965e+00,
#           1.8964e+00,  4.1971e-01],
#         [-1.5776e-02, -2.6007e-01, -1.0788e-01,  ...,  5.3392e+00,
#           1.0892e+00, -7.6439e-02],
#         [-1.4778e-02, -2.6174e-01, -1.0891e-01,  ...,  5.3547e+00,
#           1.1083e+00, -7.5757e-02],
#         ...,
#         [ 1.0214e+00, -1.8633e-01, -6.2674e-02,  ...,  1.0789e+01,
#           9.2702e-01, -1.6401e-01],
#         [ 9.7935e-01, -1.8793e-01, -6.3724e-02,  ...,  1.0797e+01,
#           9.3492e-01, -1.6539e-01],
#         [ 2.2719e+00, -2.4822e-01, -4.7583e-02,  ...,  9.2296e+00,
#           2.7330e+00,  5.3947e-02]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([6504, 16])
# X_init:  5
# torch.Size([4090, 3])
# X_interme_enc:  torch.Size([4090, 64])
# X_interme_enc:  torch.Size([4090, 128])
# X_interme_enc:  torch.Size([3396, 128])
# X_interme_enc:  torch.Size([3396, 256])
# X_interme_enc:  torch.Size([3396, 256])
# X_interme_enc:  torch.Size([1962, 256])
# X_interme_enc:  torch.Size([1962, 512])
# X_interme_enc:  torch.Size([1962, 512])
# X_interme_enc:  torch.Size([927, 512])
# X_interme_enc:  torch.Size([927, 1024])
# X_interme_enc:  torch.Size([927, 1024])
# X_interme_enc:  torch.Size([387, 1024])
# X_interme_enc:  torch.Size([387, 2048])
# X_interme_dec:  torch.Size([927, 2048])
# X_interme_dec:  torch.Size([927, 1024])
# X_interme_dec:  torch.Size([1962, 1024])
# X_interme_dec:  torch.Size([1962, 512])
# X_interme_dec:  torch.Size([3396, 512])
# X_interme_dec:  torch.Size([3396, 256])
# X_interme_dec:  torch.Size([4090, 256])
# X_interme_dec:  torch.Size([4090, 128])
# X_fin:  torch.Size([4090, 128])
# X_fin:  torch.Size([4090, 16])
# tensor([[ 1.3970, -0.0696, -0.0438,  ...,  2.7479,  3.8642,  6.1296],
#         [ 1.5264, -0.0857, -0.0444,  ...,  2.6795,  3.8442,  6.2158],
#         [-0.1032, -0.0333,  1.3872,  ...,  2.5957,  4.0194, 12.2456],
#         ...,
#         [ 1.3315, -0.1865, -0.1721,  ..., 10.6823,  3.6771,  6.0251],
#         [ 1.2366,  0.6184, -0.0365,  ...,  3.0391,  5.3101, 10.0265],
#         [ 1.2527, -0.1477, -0.1643,  ..., 10.4505,  3.7130,  6.1056]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([4090, 16])
# X_init:  5
# torch.Size([6503, 3])
# X_interme_enc:  torch.Size([6503, 64])
# X_interme_enc:  torch.Size([6503, 128])
# X_interme_enc:  torch.Size([4392, 128])
# X_interme_enc:  torch.Size([4392, 256])
# X_interme_enc:  torch.Size([4392, 256])
# X_interme_enc:  torch.Size([2494, 256])
# X_interme_enc:  torch.Size([2494, 512])
# X_interme_enc:  torch.Size([2494, 512])
# X_interme_enc:  torch.Size([1199, 512])
# X_interme_enc:  torch.Size([1199, 1024])
# X_interme_enc:  torch.Size([1199, 1024])
# X_interme_enc:  torch.Size([548, 1024])
# X_interme_enc:  torch.Size([548, 2048])
# X_interme_dec:  torch.Size([1199, 2048])
# X_interme_dec:  torch.Size([1199, 1024])
# X_interme_dec:  torch.Size([2494, 1024])
# X_interme_dec:  torch.Size([2494, 512])
# X_interme_dec:  torch.Size([4392, 512])
# X_interme_dec:  torch.Size([4392, 256])
# X_interme_dec:  torch.Size([6503, 256])
# X_interme_dec:  torch.Size([6503, 128])
# X_fin:  torch.Size([6503, 128])
# X_fin:  torch.Size([6503, 16])
# tensor([[ 0.5161, -0.2423, -0.0981,  ...,  6.0497,  3.0638, -0.0244],
#         [ 0.2505, -0.2527, -0.0883,  ...,  6.1661,  2.7554, -0.0377],
#         [ 0.4233, -0.2558, -0.0872,  ...,  6.2077,  2.9026, -0.0250],
#         ...,
#         [-0.0120, -0.2336, -0.0329,  ...,  7.6275,  2.8384, -0.0790],
#         [-0.0114, -0.1832, -0.0495,  ...,  5.5486,  2.5933,  1.7863],
#         [ 0.3453, -0.2033, -0.0626,  ...,  5.2550,  2.2946,  1.3410]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([6503, 16])
# X_init:  5
# torch.Size([2510, 3])
# X_interme_enc:  torch.Size([2510, 64])
# X_interme_enc:  torch.Size([2510, 128])
# X_interme_enc:  torch.Size([2418, 128])
# X_interme_enc:  torch.Size([2418, 256])
# X_interme_enc:  torch.Size([2418, 256])
# X_interme_enc:  torch.Size([1781, 256])
# X_interme_enc:  torch.Size([1781, 512])
# X_interme_enc:  torch.Size([1781, 512])
# X_interme_enc:  torch.Size([933, 512])
# X_interme_enc:  torch.Size([933, 1024])
# X_interme_enc:  torch.Size([933, 1024])
# X_interme_enc:  torch.Size([405, 1024])
# X_interme_enc:  torch.Size([405, 2048])
# X_interme_dec:  torch.Size([933, 2048])
# X_interme_dec:  torch.Size([933, 1024])
# X_interme_dec:  torch.Size([1781, 1024])
# X_interme_dec:  torch.Size([1781, 512])
# X_interme_dec:  torch.Size([2418, 512])
# X_interme_dec:  torch.Size([2418, 256])
# X_interme_dec:  torch.Size([2510, 256])
# X_interme_dec:  torch.Size([2510, 128])
# X_fin:  torch.Size([2510, 128])
# X_fin:  torch.Size([2510, 16])
# tensor([[-1.9177e-02, -1.8704e-01, -9.3202e-02,  ...,  4.3223e+00,
#           3.0569e+00,  3.1737e+00],
#         [-1.1150e-02, -2.0832e-01, -9.7634e-02,  ...,  4.4856e+00,
#           3.5368e+00,  3.1739e+00],
#         [ 5.6961e-01, -1.2016e-01, -4.3853e-02,  ...,  1.0054e+01,
#           3.6446e+00,  1.3933e+00],
#         ...,
#         [ 1.9921e+00, -9.6964e-02, -8.8886e-02,  ...,  9.8735e+00,
#           4.0279e+00,  1.9942e+00],
#         [ 1.6959e+00,  6.4111e-01, -3.9426e-02,  ...,  1.2214e+01,
#           5.6445e+00,  4.8565e+00],
#         [ 1.7211e+00,  1.9924e-02, -2.7849e-02,  ...,  1.2234e+01,
#           6.5981e+00,  5.3252e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([2510, 16])
# X_init:  5
# torch.Size([7896, 3])
# X_interme_enc:  torch.Size([7896, 64])
# X_interme_enc:  torch.Size([7896, 128])
# X_interme_enc:  torch.Size([4265, 128])
# X_interme_enc:  torch.Size([4265, 256])
# X_interme_enc:  torch.Size([4265, 256])
# X_interme_enc:  torch.Size([1787, 256])
# X_interme_enc:  torch.Size([1787, 512])
# X_interme_enc:  torch.Size([1787, 512])
# X_interme_enc:  torch.Size([678, 512])
# X_interme_enc:  torch.Size([678, 1024])
# X_interme_enc:  torch.Size([678, 1024])
# X_interme_enc:  torch.Size([218, 1024])
# X_interme_enc:  torch.Size([218, 2048])
# X_interme_dec:  torch.Size([678, 2048])
# X_interme_dec:  torch.Size([678, 1024])
# X_interme_dec:  torch.Size([1787, 1024])
# X_interme_dec:  torch.Size([1787, 512])
# X_interme_dec:  torch.Size([4265, 512])
# X_interme_dec:  torch.Size([4265, 256])
# X_interme_dec:  torch.Size([7896, 256])
# X_interme_dec:  torch.Size([7896, 128])
# X_fin:  torch.Size([7896, 128])
# X_fin:  torch.Size([7896, 16])
# ...
#         [ 1.8774,  0.5994,  1.3386,  ...,  2.2242, 10.6778,  5.6885]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([9933, 16])
# X_init:  5
# torch.Size([8319, 3])
# X_interme_enc:  torch.Size([8319, 64])
# X_interme_enc:  torch.Size([8319, 128])
# X_interme_enc:  torch.Size([6534, 128])
# X_interme_enc:  torch.Size([6534, 256])
# X_interme_enc:  torch.Size([6534, 256])
# X_interme_enc:  torch.Size([3564, 256])
# X_interme_enc:  torch.Size([3564, 512])
# X_interme_enc:  torch.Size([3564, 512])
# X_interme_enc:  torch.Size([1563, 512])
# X_interme_enc:  torch.Size([1563, 1024])
# X_interme_enc:  torch.Size([1563, 1024])
# X_interme_enc:  torch.Size([621, 1024])
# X_interme_enc:  torch.Size([621, 2048])
# X_interme_dec:  torch.Size([1563, 2048])
# X_interme_dec:  torch.Size([1563, 1024])
# X_interme_dec:  torch.Size([3564, 1024])
# X_interme_dec:  torch.Size([3564, 512])
# X_interme_dec:  torch.Size([6534, 512])
# X_interme_dec:  torch.Size([6534, 256])
# X_interme_dec:  torch.Size([8319, 256])
# X_interme_dec:  torch.Size([8319, 128])
# X_fin:  torch.Size([8319, 128])
# X_fin:  torch.Size([8319, 16])
# tensor([[ 3.6009e+00,  4.4891e-01,  2.2259e+00,  ...,  2.5598e+00,
#           1.2579e+01,  5.2792e+00],
#         [ 3.7011e+00,  2.0279e-01,  2.6067e+00,  ...,  2.6016e+00,
#           1.2186e+01,  4.9861e+00],
#         [ 3.7091e+00, -5.4732e-03,  2.5204e+00,  ...,  2.4346e+00,
#           1.2437e+01,  5.0556e+00],
#         ...,
#         [ 4.1718e+00, -3.5711e-02,  5.5939e-01,  ...,  2.8542e+00,
#           1.3753e+01,  4.6561e+00],
#         [ 3.3806e+00, -5.9661e-02,  1.0128e+00,  ...,  2.5543e+00,
#           1.2980e+01,  5.0863e+00],
#         [ 4.2188e+00, -1.2130e-01,  7.7194e-01,  ...,  3.4252e+00,
#           1.2191e+01,  4.0129e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([8319, 16])
# X_init:  5
# torch.Size([4579, 3])
# X_interme_enc:  torch.Size([4579, 64])
# X_interme_enc:  torch.Size([4579, 128])
# X_interme_enc:  torch.Size([4243, 128])
# X_interme_enc:  torch.Size([4243, 256])
# X_interme_enc:  torch.Size([4243, 256])
# X_interme_enc:  torch.Size([3334, 256])
# X_interme_enc:  torch.Size([3334, 512])
# X_interme_enc:  torch.Size([3334, 512])
# X_interme_enc:  torch.Size([2030, 512])
# X_interme_enc:  torch.Size([2030, 1024])
# X_interme_enc:  torch.Size([2030, 1024])
# X_interme_enc:  torch.Size([995, 1024])
# X_interme_enc:  torch.Size([995, 2048])
# X_interme_dec:  torch.Size([2030, 2048])
# X_interme_dec:  torch.Size([2030, 1024])
# X_interme_dec:  torch.Size([3334, 1024])
# X_interme_dec:  torch.Size([3334, 512])
# X_interme_dec:  torch.Size([4243, 512])
# X_interme_dec:  torch.Size([4243, 256])
# X_interme_dec:  torch.Size([4579, 256])
# X_interme_dec:  torch.Size([4579, 128])
# X_fin:  torch.Size([4579, 128])
# X_fin:  torch.Size([4579, 16])
# tensor([[ 2.9361e-01,  5.5775e-01, -1.0013e-01,  ...,  8.3529e+00,
#           3.8677e+00,  8.1077e+00],
#         [ 2.8068e-01,  7.1784e-01, -6.2535e-02,  ...,  8.6689e+00,
#           3.6007e+00,  5.2126e+00],
#         [ 7.5162e-01,  3.8596e-01, -1.0562e-01,  ...,  9.6871e+00,
#           4.1555e+00,  8.9218e+00],
#         ...,
#         [-6.2097e-02, -3.5257e-02,  1.0468e+00,  ...,  3.2712e+00,
#           3.5630e+00,  1.3130e+01],
#         [-4.6678e-02, -1.7277e-03,  1.2051e+00,  ...,  4.4047e+00,
#           4.2616e+00,  1.4026e+01],
#         [ 1.2054e+00, -9.1690e-02,  5.9285e-02,  ...,  2.5351e+00,
#           5.8539e+00,  5.9020e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([4579, 16])
# X_init:  5
# torch.Size([15716, 3])
# X_interme_enc:  torch.Size([15716, 64])
# X_interme_enc:  torch.Size([15716, 128])
# X_interme_enc:  torch.Size([12652, 128])
# X_interme_enc:  torch.Size([12652, 256])
# X_interme_enc:  torch.Size([12652, 256])
# X_interme_enc:  torch.Size([7006, 256])
# X_interme_enc:  torch.Size([7006, 512])
# X_interme_enc:  torch.Size([7006, 512])
# X_interme_enc:  torch.Size([2913, 512])
# X_interme_enc:  torch.Size([2913, 1024])
# X_interme_enc:  torch.Size([2913, 1024])
# X_interme_enc:  torch.Size([1069, 1024])
# X_interme_enc:  torch.Size([1069, 2048])
# X_interme_dec:  torch.Size([2913, 2048])
# X_interme_dec:  torch.Size([2913, 1024])
# X_interme_dec:  torch.Size([7006, 1024])
# X_interme_dec:  torch.Size([7006, 512])
# X_interme_dec:  torch.Size([12652, 512])
# X_interme_dec:  torch.Size([12652, 256])
# X_interme_dec:  torch.Size([15716, 256])
# X_interme_dec:  torch.Size([15716, 128])
# X_fin:  torch.Size([15716, 128])
# X_fin:  torch.Size([15716, 16])
# tensor([[ 1.3229e+00,  7.5374e-01, -6.7015e-02,  ...,  1.1638e+01,
#           4.0328e+00,  6.3224e+00],
#         [ 1.0887e+00, -1.3574e-02, -8.9314e-02,  ...,  1.2128e+01,
#           4.4563e+00,  6.0247e+00],
#         [ 2.8654e-01, -6.8957e-03, -1.5208e-02,  ...,  9.8113e+00,
#           3.1893e+00,  3.5328e+00],
#         ...,
#         [ 2.8555e-01, -2.8576e-02, -4.5222e-02,  ...,  1.3295e+01,
#           5.3311e+00,  4.1740e+00],
#         [ 1.2175e+00, -2.9696e-01,  1.1072e+00,  ...,  3.1149e+00,
#           6.5557e+00,  1.5648e+01],
#         [ 6.3266e-01, -1.7391e-01,  1.3339e+00,  ...,  4.0125e+00,
#           6.6202e+00,  1.5775e+01]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([15716, 16])
# X_init:  5
# torch.Size([50924, 3])
# X_interme_enc:  torch.Size([50924, 64])
# X_interme_enc:  torch.Size([50924, 128])
# X_interme_enc:  torch.Size([28046, 128])
# X_interme_enc:  torch.Size([28046, 256])
# X_interme_enc:  torch.Size([28046, 256])
# X_interme_enc:  torch.Size([10481, 256])
# X_interme_enc:  torch.Size([10481, 512])
# X_interme_enc:  torch.Size([10481, 512])
# X_interme_enc:  torch.Size([3179, 512])
# X_interme_enc:  torch.Size([3179, 1024])
# X_interme_enc:  torch.Size([3179, 1024])
# X_interme_enc:  torch.Size([855, 1024])
# X_interme_enc:  torch.Size([855, 2048])
# X_interme_dec:  torch.Size([3179, 2048])
# X_interme_dec:  torch.Size([3179, 1024])
# X_interme_dec:  torch.Size([10481, 1024])
# X_interme_dec:  torch.Size([10481, 512])
# X_interme_dec:  torch.Size([28046, 512])
# X_interme_dec:  torch.Size([28046, 256])
# X_interme_dec:  torch.Size([50924, 256])
# X_interme_dec:  torch.Size([50924, 128])
# X_fin:  torch.Size([50924, 128])
# X_fin:  torch.Size([50924, 16])
# tensor([[-0.0378, -0.1941, -0.0587,  ...,  9.8473,  4.0271,  3.0902],
#         [ 0.2492, -0.1472, -0.0678,  ...,  8.3981,  2.7589,  3.7231],
#         [ 1.3300, -0.0665, -0.0791,  ...,  6.4030,  2.1808,  3.5781],
#         ...,
#         [ 2.8261,  0.4635, -0.1109,  ...,  5.5371,  4.4147, 12.3396],
#         [-0.0193, -0.3757,  1.1846,  ...,  7.2355,  2.7205, -0.1021],
#         [ 0.9683,  1.0050,  1.2901,  ...,  2.7320,  7.1180, 12.4183]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([50924, 16])
# X_init:  5
# torch.Size([36144, 3])
# X_interme_enc:  torch.Size([36144, 64])
# X_interme_enc:  torch.Size([36144, 128])
# X_interme_enc:  torch.Size([22264, 128])
# X_interme_enc:  torch.Size([22264, 256])
# X_interme_enc:  torch.Size([22264, 256])
# X_interme_enc:  torch.Size([9323, 256])
# X_interme_enc:  torch.Size([9323, 512])
# X_interme_enc:  torch.Size([9323, 512])
# X_interme_enc:  torch.Size([3228, 512])
# X_interme_enc:  torch.Size([3228, 1024])
# X_interme_enc:  torch.Size([3228, 1024])
# X_interme_enc:  torch.Size([1003, 1024])
# X_interme_enc:  torch.Size([1003, 2048])
# X_interme_dec:  torch.Size([3228, 2048])
# X_interme_dec:  torch.Size([3228, 1024])
# X_interme_dec:  torch.Size([9323, 1024])
# X_interme_dec:  torch.Size([9323, 512])
# X_interme_dec:  torch.Size([22264, 512])
# X_interme_dec:  torch.Size([22264, 256])
# X_interme_dec:  torch.Size([36144, 256])
# X_interme_dec:  torch.Size([36144, 128])
# X_fin:  torch.Size([36144, 128])
# X_fin:  torch.Size([36144, 16])
# tensor([[ 2.5182e+00, -7.2920e-02, -1.2651e-01,  ...,  1.2277e+01,
#           4.9118e+00,  2.7076e+00],
#         [ 2.1203e+00, -3.3478e-03, -1.4874e-01,  ...,  1.2607e+01,
#           4.0636e+00,  3.2581e+00],
#         [ 2.7668e+00, -5.4641e-02, -1.5478e-01,  ...,  1.2520e+01,
#           3.8427e+00,  2.8743e+00],
#         ...,
#         [ 2.2561e+00, -1.3350e-01, -7.5183e-02,  ...,  1.3300e+01,
#           3.7581e+00,  1.7054e-01],
#         [ 7.1553e-01,  1.8114e+00,  2.0151e-01,  ...,  7.3425e+00,
#           6.1325e+00,  1.1177e+01],
#         [ 3.8311e+00, -1.5496e-02, -4.8468e-02,  ...,  1.4733e+01,
#           4.6458e+00,  2.6958e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([36144, 16])
# X_init:  5
# torch.Size([49259, 3])
# X_interme_enc:  torch.Size([49259, 64])
# X_interme_enc:  torch.Size([49259, 128])
# X_interme_enc:  torch.Size([27146, 128])
# X_interme_enc:  torch.Size([27146, 256])
# X_interme_enc:  torch.Size([27146, 256])
# X_interme_enc:  torch.Size([10246, 256])
# X_interme_enc:  torch.Size([10246, 512])
# X_interme_enc:  torch.Size([10246, 512])
# X_interme_enc:  torch.Size([2981, 512])
# X_interme_enc:  torch.Size([2981, 1024])
# X_interme_enc:  torch.Size([2981, 1024])
# X_interme_enc:  torch.Size([904, 1024])
# X_interme_enc:  torch.Size([904, 2048])
# X_interme_dec:  torch.Size([2981, 2048])
# X_interme_dec:  torch.Size([2981, 1024])
# X_interme_dec:  torch.Size([10246, 1024])
# X_interme_dec:  torch.Size([10246, 512])
# X_interme_dec:  torch.Size([27146, 512])
# X_interme_dec:  torch.Size([27146, 256])
# X_interme_dec:  torch.Size([49259, 256])
# X_interme_dec:  torch.Size([49259, 128])
# X_fin:  torch.Size([49259, 128])
# X_fin:  torch.Size([49259, 16])
# tensor([[ 7.7665e-01, -1.3886e-01, -1.0489e-01,  ...,  1.2557e+01,
#           3.2436e+00,  2.2417e+00],
#         [ 4.7265e-01, -9.3696e-02, -9.0945e-02,  ...,  1.1867e+01,
#           2.8528e+00,  2.5146e+00],
#         [ 1.2346e+00, -1.4063e-01, -6.0137e-02,  ...,  1.0495e+01,
#           2.2909e+00,  2.6605e+00],
#         ...,
#         [ 1.4483e-01, -8.6749e-02, -6.6764e-02,  ...,  4.6116e+00,
#           3.6443e+00,  1.2840e+01],
#         [ 1.4630e+00, -1.3423e-02,  1.5698e+00,  ...,  2.5317e+00,
#           4.6638e+00,  1.1253e+01],
#         [ 2.8496e+00, -4.5142e-02, -1.7098e-01,  ...,  1.5025e+01,
#           3.1827e+00,  5.7338e+00]], device='cuda:0',
#        grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([49259, 16])
# X_init:  5
# torch.Size([10768, 3])
# X_interme_enc:  torch.Size([10768, 64])
# X_interme_enc:  torch.Size([10768, 128])
# X_interme_enc:  torch.Size([9444, 128])
# X_interme_enc:  torch.Size([9444, 256])
# X_interme_enc:  torch.Size([9444, 256])
# X_interme_enc:  torch.Size([5820, 256])
# X_interme_enc:  torch.Size([5820, 512])
# X_interme_enc:  torch.Size([5820, 512])
# X_interme_enc:  torch.Size([2543, 512])
# X_interme_enc:  torch.Size([2543, 1024])
# X_interme_enc:  torch.Size([2543, 1024])
# X_interme_enc:  torch.Size([907, 1024])
# X_interme_enc:  torch.Size([907, 2048])
# X_interme_dec:  torch.Size([2543, 2048])
# X_interme_dec:  torch.Size([2543, 1024])
# X_interme_dec:  torch.Size([5820, 1024])
# X_interme_dec:  torch.Size([5820, 512])
# X_interme_dec:  torch.Size([9444, 512])
# X_interme_dec:  torch.Size([9444, 256])
# X_interme_dec:  torch.Size([10768, 256])
# X_interme_dec:  torch.Size([10768, 128])
# X_fin:  torch.Size([10768, 128])
# X_fin:  torch.Size([10768, 16])
# tensor([[-0.0638, -0.2180,  0.0283,  ...,  4.2971,  3.4815,  0.3063],
#         [-0.0720, -0.2380,  0.2314,  ...,  4.8185,  3.5209,  0.3192],
#         [-0.0555, -0.2541,  0.1275,  ...,  4.9120,  3.4816,  0.1725],
#         ...,
#         [ 1.3657, -0.0662, -0.1155,  ..., 11.3042,  3.9612,  4.1587],
#         [ 0.0386, -0.0728, -0.1143,  ...,  8.8435,  3.8269,  6.1483],
#         [ 0.2929, -0.0314, -0.0883,  ..., 11.1844,  3.5958,  6.1904]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([10768, 16])
# X_init:  5
# torch.Size([52008, 3])
# X_interme_enc:  torch.Size([52008, 64])
# X_interme_enc:  torch.Size([52008, 128])
# X_interme_enc:  torch.Size([18469, 128])
# X_interme_enc:  torch.Size([18469, 256])
# X_interme_enc:  torch.Size([18469, 256])
# X_interme_enc:  torch.Size([5403, 256])
# X_interme_enc:  torch.Size([5403, 512])
# X_interme_enc:  torch.Size([5403, 512])
# X_interme_enc:  torch.Size([1343, 512])
# X_interme_enc:  torch.Size([1343, 1024])
# X_interme_enc:  torch.Size([1343, 1024])
# X_interme_enc:  torch.Size([386, 1024])
# X_interme_enc:  torch.Size([386, 2048])
# X_interme_dec:  torch.Size([1343, 2048])
# X_interme_dec:  torch.Size([1343, 1024])
# X_interme_dec:  torch.Size([5403, 1024])
# X_interme_dec:  torch.Size([5403, 512])
# X_interme_dec:  torch.Size([18469, 512])
# X_interme_dec:  torch.Size([18469, 256])
# X_interme_dec:  torch.Size([52008, 256])
# X_interme_dec:  torch.Size([52008, 128])
# X_fin:  torch.Size([52008, 128])
# X_fin:  torch.Size([52008, 16])
# tensor([[ 0.2652, -0.1773, -0.0426,  ...,  8.5743,  2.7016,  0.3590],
#         [ 0.1202, -0.1927, -0.0211,  ...,  7.6984,  2.4966,  0.2456],
#         [ 0.0950, -0.1582, -0.0360,  ...,  6.9966,  2.2190,  0.5376],
#         ...,
#         [ 0.8072, -0.0131, -0.0887,  ..., 10.9105,  2.8754,  2.5679],
#         [ 0.4743,  0.5611,  2.9656,  ...,  3.5112,  7.2752, 10.6871],
#         [-0.0188,  1.2348,  0.9986,  ...,  6.5157,  9.4557,  6.2354]],
#        device='cuda:0', grad_fn=<LeakyReluBackward0>)
# Output here?
# torch.Size([52008, 16])
# Sequence: 08, subsample number 1/1:   0%|▏                                         | 14/4071 [03:55<25:59:17, 23.06s/it]
# Processing dataset semantickitti:   0%|                                                           | 0/1 [04:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21017/1479510310.py in <module>
#      71     #    ius, miu = valid_dataset.compute_results()
#      72     #except:
# ---> 73     valid_dataset.compute_dataset()
#      74     ius, miu = valid_dataset.compute_results() # The results are already there?
#      75     print(ius)
#
# /home/3DLabelProp/datasets/inference_dataset.py in compute_dataset(self)
#     165         print("Sequence: ", self.trg_datast.sequence)
#     166         for i in tqdm(range(len(self.trg_datast.sequence)),desc="Processing dataset "+str(self.config.target)):
# --> 167             self.compute_sequence(i)
#     168
#     169     def compute_sequence(self,seq_number):
#
# /home/3DLabelProp/datasets/inference_dataset.py in compute_sequence(self, seq_number)
#     251                 # Predictions are made here :0
#     252                 #print("Total_Pred")
# --> 253                 total_pred = self.infer_concat(self.model,[accumulated_pointcloud[c] for c in clusters],self.device,self.cfg_model,1)
#     254                 predicted_cloudwise = np.zeros((len(accumulated_pointcloud),self.n_label+1))
#     255                 for i in range(len(clusters)):
#
# /home/3DLabelProp/datasets/inference_dataset.py in infer_concat_kp(model, clusters, device, config_model, batch_size)
#      63         l=0
#      64         sub_clusters = clusters[k*batch_size:min((k+1)*batch_size,len(clusters))]
# ---> 65         r_clouds, r_inds_list = model.prepare_data(sub_clusters,False,True)
#      66         if 'cuda' in device.type:
#      67             r_clouds.to(device)
#
# /home/3DLabelProp/models/kpconv_model.py in prepare_data(self, pointclouds, augment, eval)
#     369                                               stacked_features,
#     370                                               labels.astype(np.int64),
# --> 371                                               np.array(size, dtype=np.int32))
#     372
#     373         return self.batch([self.model_config.num_layers] + input_list + [timestamps]), r_inds_list
#
# /home/3DLabelProp/models/kpconv/common.py in segmentation_inputs(self, stacked_points, stacked_features, labels, stack_lengths)
#     413
#     414                 # Upsample indices (with the radius of the next layer to keep wanted density)
# --> 415                 up_i = batch_neighbors(stacked_points, pool_p, stack_lengths, pool_b, 2 * r)
#     416
#     417             else:
#
# /home/3DLabelProp/models/kpconv/common.py in batch_neighbors(queries, supports, q_batches, s_batches, radius)
#     192     """
#     193
# --> 194     return cpp_neighbors.batch_query(queries, supports, q_batches, s_batches, radius=radius)
#     195
#     196
#
# KeyboardInterrupt:
